# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.
# All rights reserved.

# This source code is licensed under the license found in the
# LICENSE file in the root directory of this source tree.
# --------------------------------------------------------
# References:
# DeiT: https://github.com/facebookresearch/deit
# BEiT: https://github.com/microsoft/unilm/tree/master/beit
# --------------------------------------------------------

import timm.optim.optim_factory as optim_factory
import argparse
import datetime
import json
import numpy as np
import os
import time
from pathlib import Path

import torch
import torch.backends.cudnn as cudnn
from torch.utils.tensorboard import SummaryWriter

import timm

# assert timm.__version__ == "0.3.2" # version check
from timm.models.layers import trunc_normal_
from timm.data.mixup import Mixup
from timm.loss import LabelSmoothingCrossEntropy, SoftTargetCrossEntropy

import util.lr_decay as lrd
import util.misc as misc
from util.datasets import build_dataset
from util.pos_embed import interpolate_pos_embed
from util.misc import NativeScalerWithGradNormCount as NativeScaler

import models_vit

from engine_finetune import train_one_epoch, evaluate


def get_args_parser():
    parser = argparse.ArgumentParser('MAE fine-tuning for image segmentation', add_help=False)
    parser.add_argument('--batch_size', default=64, type=int,
                        help='Batch size per GPU (effective batch size is batch_size * accum_iter * # gpus')
    parser.add_argument('--epochs', default=300, type=int)
    parser.add_argument('--accum_iter', default=1, type=int,
                        help='Accumulate gradient iterations (for increasing the effective batch size under memory constraints)')

    # Model parameters
    parser.add_argument('--model', default='mae_vit_base_patch16', type=str, metavar='MODEL',
                        help='Name of model to train')

    parser.add_argument('--input_size', default=224, type=int,
                        help='images input size')

    parser.add_argument('--drop_path', type=float, default=0.1, metavar='PCT',
                        help='Drop path rate (default: 0.1)')

    # Optimizer parameters
    parser.add_argument('--clip_grad', type=float, default=None, metavar='NORM',
                        help='Clip gradient norm (default: None, no clipping)')
    parser.add_argument('--weight_decay', type=float, default=0.0015,
                        help='weight decay (default: 0.05)')

    parser.add_argument('--lr', type=float, default=1e-4, metavar='LR',
                        help='learning rate (absolute lr)')
    parser.add_argument('--blr', type=float, default=1e-4, metavar='LR',
                        help='base learning rate: absolute_lr = base_lr * total_batch_size / 256')
    parser.add_argument('--layer_decay', type=float, default=0.5,
                        help='layer-wise lr decay from ELECTRA/BEiT')

    parser.add_argument('--min_lr', type=float, default=1e-6, metavar='LR',
                        help='lower lr bound for cyclic schedulers that hit 0')

    parser.add_argument('--warmup_epochs', type=int, default=5, metavar='N',
                        help='epochs to warmup LR')

    # Augmentation parameters
    parser.add_argument('--color_jitter', type=float, default=None, metavar='PCT',
                        help='Color jitter factor (enabled only when not using Auto/RandAug)')
    parser.add_argument('--aa', type=str, default='rand-m9-mstd0.5-inc1', metavar='NAME',
                        help='Use AutoAugment policy. "v0" or "original". " + "(default: rand-m9-mstd0.5-inc1)'),
    parser.add_argument('--smoothing', type=float, default=0.1,
                        help='Label smoothing (default: 0.1)')

    # * Random Erase params
    parser.add_argument('--reprob', type=float, default=0.25, metavar='PCT',
                        help='Random erase prob (default: 0.25)')
    parser.add_argument('--remode', type=str, default='pixel',
                        help='Random erase mode (default: "pixel")')
    parser.add_argument('--recount', type=int, default=1,
                        help='Random erase count (default: 1)')
    parser.add_argument('--resplit', action='store_true', default=False,
                        help='Do not random erase first (clean) augmentation split')

    # * Mixup params
    parser.add_argument('--mixup', type=float, default=0,
                        help='mixup alpha, mixup enabled if > 0.')
    parser.add_argument('--cutmix', type=float, default=0,
                        help='cutmix alpha, cutmix enabled if > 0.')
    parser.add_argument('--cutmix_minmax', type=float, nargs='+', default=None,
                        help='cutmix min/max ratio, overrides alpha and enables cutmix if set (default: None)')
    parser.add_argument('--mixup_prob', type=float, default=1.0,
                        help='Probability of performing mixup or cutmix when either/both is enabled')
    parser.add_argument('--mixup_switch_prob', type=float, default=0.5,
                        help='Probability of switching to cutmix when both mixup and cutmix enabled')
    parser.add_argument('--mixup_mode', type=str, default='batch',
                        help='How to apply mixup/cutmix params. Per "batch", "pair", or "elem"')

    # * Finetuning params
    parser.add_argument('--finetune', default='/data/zhanghao/skull_project/mae-main/pretrain_output_dir/checkpoint-399.pth',
                        help='finetune from checkpoint')
    parser.add_argument('--global_pool', action='store_true')
    parser.set_defaults(global_pool=True)
    parser.add_argument('--cls_token', action='store_false', dest='global_pool',
                        help='Use class token instead of global pool for classification')

    # Dataset parameters
    parser.add_argument('--data_path', default='/datasets01/imagenet_full_size/061417/', type=str,
                        help='dataset path')
    parser.add_argument('--nb_classes', default=1000, type=int,
                        help='number of the classification types')

    parser.add_argument('--output_dir', default='./mae-main/base_line/mae2d_cc359_020data',
                        help='path where to save, empty for no saving')
    parser.add_argument('--log_dir', default='./mae-main/base_line/mae2d_cc359_020data',
                        help='path where to tensorboard log')
    parser.add_argument('--device', default='cuda:1',
                        help='device to use for training / testing')
    parser.add_argument('--seed', default=0, type=int)
    parser.add_argument('--resume', default='',
                        help='resume from checkpoint')

    parser.add_argument('--start_epoch', default=0, type=int, metavar='N',
                        help='start epoch')
    parser.add_argument('--eval', action='store_true',
                        help='Perform evaluation only')
    parser.add_argument('--dist_eval', action='store_true', default=False,
                        help='Enabling distributed evaluation (recommended during training for faster monitor')
    parser.add_argument('--num_workers', default=10, type=int)
    parser.add_argument('--pin_mem', action='store_true',
                        help='Pin CPU memory in DataLoader for more efficient (sometimes) transfer to GPU.')
    parser.add_argument('--no_pin_mem', action='store_false', dest='pin_mem')
    parser.set_defaults(pin_mem=True)

    # distributed training parameters
    parser.add_argument('--world_size', default=1, type=int,
                        help='number of distributed processes')
    parser.add_argument('--local_rank', default=-1, type=int)
    parser.add_argument('--dist_on_itp', action='store_true')
    parser.add_argument('--dist_url', default='env://',
                        help='url used to set up distributed training')

    return parser

# %%
from util.ccdataset import *
train_path, valid_path, test_path = getPathList()
train_loader = getDataloader020(
    train_path, B1=1)
_,valid_loader,test_loader = getDataloader(
    train_path,valid_path,test_path
)
len(train_loader),len(valid_loader),len(test_loader)
#(1,1,160,224,224)
# Out:
# (92, 6880, 6720)

# %% [markdown]
# # 不冻结decoder权重的finetune

# %%
import my_seg_vit
import util.lr_sched as lr_sched
import math
import sys
from my_metric import dice_coef_metric,jaccard_coef_metric
def main(args):   
     
    device = torch.device(args.device)

    os.makedirs(args.log_dir, exist_ok=True)
    log_writer = SummaryWriter(log_dir=args.log_dir)

    # fix the seed for reproducibility
    seed = args.seed + misc.get_rank()
    torch.manual_seed(seed)
    np.random.seed(seed) 

    cudnn.benchmark = True   

    model = my_seg_vit.__dict__[args.model](lossforpatch = False)

    #load dict
    checkpoint = torch.load(args.finetune,map_location='cpu') #一大堆参数(小数)
    print("Load pre-trained checkpoint from: %s" % args.finetune)
    checkpoint_model = checkpoint['model']
    
    state_dict = model.state_dict()
    # print('state_dict = ',state_dict)

    for k in ['head.weight', 'head.bias']:
        if k in checkpoint_model and checkpoint_model[k].shape != state_dict[k].shape:
            print(f"Removing key {k} from pretrained checkpoint")
            del checkpoint_model[k]
    
    # interpolate position embedding
    interpolate_pos_embed(model, checkpoint_model)

    # load pre-trained model
    msg = model.load_state_dict(checkpoint_model, strict=False)
    print(msg)

    model.to(device)

    model_without_ddp = model


    n_parameters = sum(p.numel() for p in model.parameters() if p.requires_grad)

    print("Model = %s" % str(model_without_ddp))
    print('number of params (M): %.2f' % (n_parameters / 1.e6))

    eff_batch_size = args.batch_size * args.accum_iter * misc.get_world_size()


    print("actual lr: %.2e" % args.lr)

    print("accumulate grad iterations: %d" % args.accum_iter)
    print("effective batch size: %d" % eff_batch_size)

    #加了layer_decay
    param_groups = lrd.param_groups_lrd(model_without_ddp, args.weight_decay,
        layer_decay=args.layer_decay
    )
    # param_groups = optim_factory.param_groups_weight_decay(
    #     model_without_ddp, args.weight_decay)
 
    optimizer = torch.optim.AdamW(param_groups, lr=args.lr)
    print("查看optimizer = ",optimizer)
    loss_scaler = NativeScaler()    

    misc.load_model(args=args, model_without_ddp=model_without_ddp, optimizer=optimizer, loss_scaler=loss_scaler)

    print(f"Start training for {args.epochs} epochs")
    dice_list = []
    start_time = time.time()

    for epoch in range(args.start_epoch, args.epochs):
        #----------------------------训练---------------------------------------------
        model.train()
        metric_logger = misc.MetricLogger(delimiter="  ")
        metric_logger.add_meter('lr', misc.SmoothedValue(window_size=1, fmt='{value:.6f}'))
        accum_iter = args.accum_iter
        optimizer.zero_grad()#优化器清零
        if log_writer is not None:
            print('log_dir: {}'.format(log_writer.log_dir))

        for data_iter_step,data in enumerate(train_loader):
            if data_iter_step % accum_iter == 0:
                lr_sched.adjust_learning_rate(optimizer, data_iter_step / len(train_loader) + epoch, args)
            samples = data["image"]  # 我自己的数据是data["image"]表示图片
            labeles = data["mask"]
            # print("mask.shape = ",labeles.shape)
            # print("samples.shape = ",samples.shape)
            # print("mask.type = ",labeles.dtype)
            samples = samples.to(device, non_blocking=True)
            labeles = labeles.to(device, non_blocking=True)

            with torch.cuda.amp.autocast():
                loss, _,  = model(samples, labeles)

            loss_value = loss.item()

            if not math.isfinite(loss_value):
                print("Loss is {}, stopping training".format(loss_value))
                sys.exit(1)

            loss /= accum_iter
            loss_scaler(loss, optimizer, parameters=model.parameters(),update_grad=(data_iter_step + 1) % accum_iter == 0)

            if (data_iter_step + 1) % accum_iter == 0:
                optimizer.zero_grad()

            torch.cuda.synchronize()

            metric_logger.update(loss=loss_value)

            lr = optimizer.param_groups[0]["lr"]
            metric_logger.update(lr=lr)

            loss_value_reduce = misc.all_reduce_mean(loss_value)

            if log_writer is not None :
                """ We use epoch_1000x as the x-axis in tensorboard.
                This calibrates different curves when batch size changes.
                """
                epoch_1000x = int(
                    (data_iter_step / len(train_loader) + epoch) * 1000)
                log_writer.add_scalar('train_loss', loss_value_reduce, epoch_1000x)
                log_writer.add_scalar('lr', lr, epoch_1000x)

        # gather the stats from all processes
        metric_logger.synchronize_between_processes()
        print("Averaged stats:", metric_logger)
        train_stats = {k: meter.global_avg for k, meter in metric_logger.meters.items()}

        #----------------------------验证-----------------------------------------------
        #每4个epoch进行一次验证
        if(epoch%4==0):
            with torch.no_grad(): #表示在验证的时候不需要梯度计算
                model.eval()
                dice_score = 0.
                iou_score = 0.
                for data in valid_loader:
                    valid_image = data["image"]
                    valid_target = data["mask"]

                    valid_image = valid_image.to(device, non_blocking=True)
                    valid_target = valid_target.to(device, non_blocking=True)

                    _,out = model(valid_image, valid_target) #[N,196,256]
                    out = model.unpatchify(out) #[N,1,224,224]
                    dice_score += dice_coef_metric(out.cpu(), valid_target.cpu())
                    iou_score += jaccard_coef_metric(out.cpu(), valid_target.cpu())
                
                dice_score /= len(valid_loader)
                iou_score /= len(valid_loader)
                print("epoch=", epoch,
                    "dice_score=", dice_score,
                    "iou_score=", iou_score)

                print("------------------------------------------------------------------")
                log_writer.add_scalar(tag="dice_scalar", scalar_value=dice_score, global_step=epoch)
                log_writer.add_scalar(tag="iou_scalar", scalar_value=iou_score, global_step=epoch)
                #原作者的save方法,封装更多内容 
                misc.save_model(args=args, model=model, model_without_ddp=model, optimizer=optimizer,
                loss_scaler=loss_scaler, epoch=epoch)
                #torch官方save方法
                torch.save(model.state_dict(), '/data/zhanghao/skull_project/mae-main/base_line/mae2d_cc359_020data/' +
                                    str(epoch) + 'ViT' + str(dice_score) + '.pth')
                

            #早停
            if epoch > 20:
                min = 999
                for i in range(int(epoch/4 - 5) , int(epoch/4 - 1) ):
                    if dice_list[i] < min:
                        min = dice_list[i]
                if dice_score < min:
                    lr /= 10
                    print(lr)
                    if lr < 1e-6:
                        break

            dice_list.append(dice_score)#依次放入epoch为0 4 8 12 16 20 24....

        log_stats = {**{f'train_{k}': v for k, v in train_stats.items()},
                     'epoch': epoch, }

        if args.output_dir and misc.is_main_process():
            if log_writer is not None:
                log_writer.flush()
            with open(os.path.join(args.output_dir, "log.txt"), mode="a", encoding="utf-8") as f:
                f.write(json.dumps(log_stats) + "\n")

    total_time = time.time() - start_time
    total_time_str = str(datetime.timedelta(seconds=int(total_time)))
    print('Training time {}'.format(total_time_str))

# %%
args = get_args_parser()
args = args.parse_args(args=[])
if args.output_dir:
    Path(args.output_dir).mkdir(parents=True, exist_ok=True)
main(args)
# Out:
# Load pre-trained checkpoint from: /data/zhanghao/skull_project/mae-main/pretrain_output_dir/checkpoint-399.pth
# _IncompatibleKeys(missing_keys=[], unexpected_keys=['mask_token'])
# Model = SegViT2D(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(1, 768, kernel_size=(16, 16), stride=(16, 16))
#     (norm): Identity()
#   )
#   (blocks): ModuleList(
#     (0): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (4): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (5): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (6): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (7): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (8): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (9): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (10): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (11): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   (decoder_embed): Linear(in_features=768, out_features=512, bias=True)
#   (decoder_blocks): ModuleList(
#     (0): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (4): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (5): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (6): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (7): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (decoder_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#   (decoder_pred): Linear(in_features=512, out_features=256, bias=True)
# )
# number of params (M): 111.00
# actual lr: 1.00e-04
# accumulate grad iterations: 1
# effective batch size: 64
# 查看optimizer =  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.0001220703125
#     weight_decay: 0.0015
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.0001220703125
#     weight_decay: 0.0
#
# Parameter Group 2
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.000244140625
#     weight_decay: 0.0
#
# Parameter Group 3
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.000244140625
#     weight_decay: 0.0015
#
# Parameter Group 4
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.00048828125
#     weight_decay: 0.0
#
# Parameter Group 5
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.00048828125
#     weight_decay: 0.0015
#
# Parameter Group 6
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.0009765625
#     weight_decay: 0.0
#
# Parameter Group 7
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.0009765625
#     weight_decay: 0.0015
#
# Parameter Group 8
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.001953125
#     weight_decay: 0.0
#
# Parameter Group 9
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.001953125
#     weight_decay: 0.0015
#
# Parameter Group 10
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.00390625
#     weight_decay: 0.0
#
# Parameter Group 11
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.00390625
#     weight_decay: 0.0015
#
# Parameter Group 12
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.0078125
#     weight_decay: 0.0
#
# Parameter Group 13
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.0078125
#     weight_decay: 0.0015
#
# Parameter Group 14
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.015625
#     weight_decay: 0.0
#
# Parameter Group 15
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.015625
#     weight_decay: 0.0015
#
# Parameter Group 16
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.03125
#     weight_decay: 0.0
#
# Parameter Group 17
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.03125
#     weight_decay: 0.0015
#
# Parameter Group 18
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.0625
#     weight_decay: 0.0
#
# Parameter Group 19
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.0625
#     weight_decay: 0.0015
#
# Parameter Group 20
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.125
#     weight_decay: 0.0
#
# Parameter Group 21
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.125
#     weight_decay: 0.0015
#
# Parameter Group 22
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.25
#     weight_decay: 0.0
#
# Parameter Group 23
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.25
#     weight_decay: 0.0015
#
# Parameter Group 24
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.5
#     weight_decay: 0.0
#
# Parameter Group 25
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.5
#     weight_decay: 0.0015
#
# Parameter Group 26
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 1.0
#     weight_decay: 0.0
#
# Parameter Group 27
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 1.0
#     weight_decay: 0.0015
# )
# Start training for 300 epochs
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.6422 (0.7023)
# epoch= 0 dice_score= 0.4343065619468689 iou_score= 0.2773892879486084
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.5500 (0.5742)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.4698 (0.5101)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.3242 (0.3899)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.1802 (0.2293)
# epoch= 4 dice_score= 0.7389277219772339 iou_score= 0.5859519243240356
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.1235 (0.1423)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.1022 (0.1093)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0892 (0.0934)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0806 (0.0835)
# epoch= 8 dice_score= 0.695652186870575 iou_score= 0.5333333611488342
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0723 (0.0763)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0687 (0.0703)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0636 (0.0649)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0585 (0.0601)
# epoch= 12 dice_score= 0.8155583143234253 iou_score= 0.6885592937469482
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0543 (0.0556)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0502 (0.0515)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0470 (0.0480)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0436 (0.0449)
# epoch= 16 dice_score= 0.7698630094528198 iou_score= 0.6258351802825928
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0410 (0.0421)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0384 (0.0396)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0360 (0.0374)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0342 (0.0353)
# epoch= 20 dice_score= 0.8062015771865845 iou_score= 0.6753246784210205
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0330 (0.0334)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0314 (0.0318)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0298 (0.0303)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0284 (0.0289)
# epoch= 24 dice_score= 0.8407643437385559 iou_score= 0.7252747416496277
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0278 (0.0277)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0261 (0.0265)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0253 (0.0254)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0241 (0.0244)
# epoch= 28 dice_score= 0.8550186157226562 iou_score= 0.7467532753944397
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0236 (0.0235)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0222 (0.0227)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0215 (0.0219)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0208 (0.0211)
# epoch= 32 dice_score= 0.8809523582458496 iou_score= 0.7872340679168701
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0204 (0.0204)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0196 (0.0197)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0189 (0.0191)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0184 (0.0185)
# epoch= 36 dice_score= 0.8596059083938599 iou_score= 0.7537797093391418
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0177 (0.0180)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0174 (0.0175)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0169 (0.0171)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0162 (0.0166)
# epoch= 40 dice_score= 0.8788598775863647 iou_score= 0.7838982939720154
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0157 (0.0161)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0154 (0.0156)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0150 (0.0151)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0145 (0.0148)
# epoch= 44 dice_score= 0.875151515007019 iou_score= 0.7780172228813171
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0142 (0.0144)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0139 (0.0141)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0138 (0.0137)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0135 (0.0135)
# epoch= 48 dice_score= 0.8899408578872681 iou_score= 0.8017057776451111
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0128 (0.0132)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0125 (0.0128)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0125 (0.0125)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0122 (0.0123)
# epoch= 52 dice_score= 0.8848921060562134 iou_score= 0.7935484051704407
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0119 (0.0120)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0117 (0.0117)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0113 (0.0114)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0110 (0.0111)
# epoch= 56 dice_score= 0.8949232697486877 iou_score= 0.80982905626297
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0106 (0.0109)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0105 (0.0107)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0104 (0.0105)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0104 (0.0104)
# epoch= 60 dice_score= 0.9026128053665161 iou_score= 0.822510838508606
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0097 (0.0102)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0097 (0.0099)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0094 (0.0097)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0095 (0.0094)
# epoch= 64 dice_score= 0.9088729023933411 iou_score= 0.8329670429229736
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0092 (0.0093)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0091 (0.0091)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0091 (0.0090)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0088 (0.0088)
# epoch= 68 dice_score= 0.9134045243263245 iou_score= 0.8406113386154175
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0087 (0.0088)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0084 (0.0085)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0083 (0.0083)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0082 (0.0081)
# epoch= 72 dice_score= 0.9097387194633484 iou_score= 0.8344226479530334
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0078 (0.0080)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0077 (0.0078)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0076 (0.0077)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0075 (0.0076)
# epoch= 76 dice_score= 0.9187279343605042 iou_score= 0.8496732115745544
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0074 (0.0074)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0072 (0.0073)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0070 (0.0072)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0069 (0.0071)
# epoch= 80 dice_score= 0.9187279343605042 iou_score= 0.8496732115745544
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0069 (0.0070)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0068 (0.0069)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0065 (0.0067)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0065 (0.0066)
# epoch= 84 dice_score= 0.9172576665878296 iou_score= 0.847161591053009
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0064 (0.0065)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0063 (0.0063)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0061 (0.0062)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0060 (0.0061)
# epoch= 88 dice_score= 0.91923987865448 iou_score= 0.8505494594573975
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0059 (0.0060)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0060 (0.0059)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0059 (0.0059)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0057 (0.0059)
# epoch= 92 dice_score= 0.9180722832679749 iou_score= 0.8485523462295532
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0056 (0.0058)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0055 (0.0056)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0054 (0.0057)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0055 (0.0055)
# epoch= 96 dice_score= 0.9378663301467896 iou_score= 0.8830022215843201
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0052 (0.0053)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0052 (0.0052)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0049 (0.0051)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0049 (0.0050)
# epoch= 100 dice_score= 0.9320619702339172 iou_score= 0.8727678656578064
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0047 (0.0049)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0049 (0.0049)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0048 (0.0048)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0047 (0.0048)
# epoch= 104 dice_score= 0.9400705099105835 iou_score= 0.8869179487228394
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0047 (0.0047)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0046 (0.0047)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0046 (0.0045)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0045 (0.0045)
# epoch= 108 dice_score= 0.9347568154335022 iou_score= 0.8775055408477783
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0042 (0.0044)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0043 (0.0043)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0043 (0.0043)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0041 (0.0043)
# epoch= 112 dice_score= 0.9396751523017883 iou_score= 0.8862144351005554
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0041 (0.0042)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0040 (0.0041)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0041 (0.0041)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0040 (0.0040)
# epoch= 116 dice_score= 0.9386792182922363 iou_score= 0.8844444155693054
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0040 (0.0040)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0038 (0.0039)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0039 (0.0038)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0037 (0.0038)
# epoch= 120 dice_score= 0.9411764740943909 iou_score= 0.8888888955116272
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0036 (0.0037)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0035 (0.0036)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0035 (0.0036)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0036 (0.0035)
# epoch= 124 dice_score= 0.9411764740943909 iou_score= 0.8888888955116272
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0034 (0.0035)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0034 (0.0034)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0033 (0.0034)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0033 (0.0034)
# epoch= 128 dice_score= 0.9400705099105835 iou_score= 0.8869179487228394
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0032 (0.0034)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0032 (0.0033)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0032 (0.0032)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0031 (0.0032)
# epoch= 132 dice_score= 0.9472450017929077 iou_score= 0.8997772932052612
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0030 (0.0031)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0031 (0.0031)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0029 (0.0030)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0029 (0.0030)
# epoch= 136 dice_score= 0.9461358189582825 iou_score= 0.897777795791626
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0029 (0.0029)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0029 (0.0029)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0029 (0.0029)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0028 (0.0029)
# epoch= 140 dice_score= 0.9471210241317749 iou_score= 0.8995535969734192
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0028 (0.0028)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0027 (0.0028)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0027 (0.0027)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0026 (0.0027)
# epoch= 144 dice_score= 0.948235273361206 iou_score= 0.9015659689903259
# ------------------------------------------------------------------
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0026 (0.0027)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0026 (0.0026)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0026 (0.0026)
# log_dir: ./mae-main/base_line/mae2d_cc359_020data
# Averaged stats: lr: 0.000000  loss: 0.0025 (0.0026)
