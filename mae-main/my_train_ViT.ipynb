# %% [markdown]
# ### 用于训练自己写的用于医学分割的ViT

# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.
# All rights reserved.

# This source code is licensed under the license found in the
# LICENSE file in the root directory of this source tree.
# --------------------------------------------------------
# References:
# DeiT: https://github.com/facebookresearch/deit
# BEiT: https://github.com/microsoft/unilm/tree/master/beit
# --------------------------------------------------------
import argparse
import datetime
import json
import numpy as np
import os
import time
from pathlib import Path
import math
import sys

import torch
import torch.backends.cudnn as cudnn
from torch.utils.tensorboard import SummaryWriter
import torchvision.transforms as transforms
import torchvision.datasets as datasets

import timm

# assert timm.__version__ == "0.3.2"  # version check
import timm.optim.optim_factory as optim_factory

import util.misc as misc
from util.misc import NativeScalerWithGradNormCount as NativeScaler

import my_seg_vit

from my_seg_engine import train_one_epoch



def get_args_parser():
    parser = argparse.ArgumentParser('my 2D supervised seg-ViT', add_help=False)
    parser.add_argument('--batch_size', default=64, type=int,
                        help='Batch size per GPU (effective batch size is batch_size * accum_iter * # gpus')
    parser.add_argument('--epochs', default=1000, type=int)
    parser.add_argument('--accum_iter', default=1, type=int,
                        help='Accumulate gradient iterations (for increasing the effective batch size under memory constraints)')

    # Model parameters
    parser.add_argument('--model', default='mae_vit_base_patch16', type=str, metavar='MODEL',
                        help='Name of model to train')

    parser.add_argument('--input_size', default=224, type=int,
                        help='images input size')

    parser.add_argument('--mask_ratio', default=0.75, type=float,
                        help='Masking ratio (percentage of removed patches).')

    parser.add_argument('--norm_pix_loss', action='store_true',
                        help='Use (per-patch) normalized pixels as targets for computing loss')
    parser.set_defaults(norm_pix_loss=False)

    # Optimizer parameters
    parser.add_argument('--weight_decay', type=float, default=0.0005,
                        help='weight decay (default: 0.05)')

    parser.add_argument('--lr', type=float, default=1e-4, metavar='LR',
                        help='learning rate (absolute lr)')
    parser.add_argument('--blr', type=float, default=1e-4, metavar='LR',
                        help='base learning rate: absolute_lr = base_lr * total_batch_size / 256')
    parser.add_argument('--min_lr', type=float, default=0., metavar='LR',
                        help='lower lr bound for cyclic schedulers that hit 0')

    parser.add_argument('--warmup_epochs', type=int, default=40, metavar='N',
                        help='epochs to warmup LR')

    # Dataset parameters
    parser.add_argument('--data_path', default='/datasets01/imagenet_full_size/061417/', type=str,
                        help='dataset path')

    parser.add_argument('--output_dir', default='./my_supervised_seg_ViT_earlystop_dice_lossforpatch',
                        help='path where to save, empty for no saving')
    parser.add_argument('--log_dir', default='./my_supervised_seg_ViT_earlystop_dice_lossforpatch',
                        help='path where to tensorboard log')
    parser.add_argument('--device', default='cuda:3',
                        help='device to use for training / testing')
    parser.add_argument('--seed', default=0, type=int)
    parser.add_argument('--resume', default='',
                        help='resume from checkpoint')

    parser.add_argument('--start_epoch', default=0, type=int, metavar='N',
                        help='start epoch')
    parser.add_argument('--num_workers', default=10, type=int)
    parser.add_argument('--pin_mem', action='store_true',
                        help='Pin CPU memory in DataLoader for more efficient (sometimes) transfer to GPU.')
    parser.add_argument('--no_pin_mem', action='store_false', dest='pin_mem')
    parser.set_defaults(pin_mem=True)

    # distributed training parameters
    parser.add_argument('--world_size', default=1, type=int,
                        help='number of distributed processes')
    parser.add_argument('--local_rank', default=-1, type=int)
    parser.add_argument('--dist_on_itp', action='store_true')
    parser.add_argument('--dist_url', default='env://',
                        help='url used to set up distributed training')

    return parser

# %%
from util.ccdataset import *
train_paths, valid_paths, test_paths = getPathList()
train_loader, valid_loader, test_loader = getDataloader(
    train_paths, valid_paths, test_paths, B1=64)
len(train_loader),len(valid_loader),len(test_loader)
# torch.Size([64, 1, 224, 224]) torch.FloatTensor
# Out:
# (685, 6880, 6720)

# %%
args = get_args_parser()
args = args.parse_args(args=[])
misc.init_distributed_mode(args)
# print('job dir: {}'.format(os.path.dirname(os.path.realpath(__file__))))
print("{}".format(args).replace(', ', ',\n'))
# Out:
# Not using distributed mode
# [18:59:38.845946] Namespace(batch_size=64,
# epochs=1000,
# accum_iter=1,
# model='mae_vit_base_patch16',
# input_size=224,
# mask_ratio=0.75,
# norm_pix_loss=False,
# weight_decay=0.0005,
# lr=0.0001,
# blr=0.0001,
# min_lr=0.0,
# warmup_epochs=40,
# data_path='/datasets01/imagenet_full_size/061417/',
# output_dir='./my_supervised_seg_ViT_earlystop_dice_lossforpatch',
# log_dir='./my_supervised_seg_ViT_earlystop_dice_lossforpatch',
# device='cuda:3',
# seed=0,
# resume='',
# start_epoch=0,
# num_workers=10,
# pin_mem=True,
# world_size=1,
# local_rank=-1,
# dist_on_itp=False,
# dist_url='env://',
# distributed=False)

# %%
from my_metric import dice_coef_metric,jaccard_coef_metric
import util.lr_sched as lr_sched
def main(args):

    print("{}".format(args).replace(', ', ',\n'))

    device = torch.device(args.device)

    # fix the seed for reproducibility
    seed = args.seed + misc.get_rank()
    torch.manual_seed(seed)
    np.random.seed(seed)

    cudnn.benchmark = True

    # if global_rank == 0 and args.log_dir is not None:
    if args.log_dir is not None:
        os.makedirs(args.log_dir, exist_ok=True)
        log_writer = SummaryWriter(log_dir=args.log_dir)


    # define the model
    model = my_seg_vit.__dict__[args.model](lossforpatch = False)

    model.to(device)

    model_without_ddp = model
    print("Model = %s" % str(model_without_ddp))


    eff_batch_size = args.batch_size * args.accum_iter * misc.get_world_size()  #64

    # if args.lr is None:  # only base_lr is specified
    #     args.lr = args.blr * eff_batch_size / 256

    print("actual lr:" , args.lr)  #使用args.lr

    print("accumulate grad iterations: %d" % args.accum_iter)
    print("effective batch size: %d" % eff_batch_size)



    param_groups = optim_factory.param_groups_weight_decay(
        model_without_ddp, args.weight_decay)

    optimizer = torch.optim.AdamW(param_groups, lr=args.lr, betas=(0.9, 0.95))

    print("查看optimizer = ",optimizer)
    loss_scaler = NativeScaler()
    misc.load_model(args=args, model_without_ddp=model_without_ddp,
                    optimizer=optimizer, loss_scaler=loss_scaler)
    print(f"Start training for {args.epochs} epochs")
    dice_list = []
    start_time = time.time()
    for epoch in range(args.start_epoch, args.epochs):
        

        #----------------------------训练---------------------------------------------
        #每个epoch设置一次优化器
        # optimizer = torch.optim.AdamW(model.parameters(), lr=args.lr, betas=(0.9, 0.95))
        model.train()
        metric_logger = misc.MetricLogger(delimiter="  ")
        metric_logger.add_meter('lr', misc.SmoothedValue(window_size=1, fmt='{value:.6f}'))
        accum_iter = args.accum_iter
        optimizer.zero_grad()#优化器清零
        if log_writer is not None:
            print('log_dir: {}'.format(log_writer.log_dir))
        
        for data_iter_step,data in enumerate(train_loader):
            if data_iter_step % accum_iter == 0:
                lr_sched.adjust_learning_rate(optimizer, data_iter_step / len(train_loader) + epoch, args)
            samples = data["image"]  # 我自己的数据是data["image"]表示图片
            labeles = data["mask"]
            # print("mask.shape = ",labeles.shape)
            # print("samples.shape = ",samples.shape)
            # print("mask.type = ",labeles.dtype)
            samples = samples.to(device, non_blocking=True)
            labeles = labeles.to(device, non_blocking=True)

            with torch.cuda.amp.autocast():
                loss, _,  = model(samples, labeles)

            loss_value = loss.item()

            if not math.isfinite(loss_value):
                print("Loss is {}, stopping training".format(loss_value))
                sys.exit(1)

            loss /= accum_iter
            loss_scaler(loss, optimizer, parameters=model.parameters(),update_grad=(data_iter_step + 1) % accum_iter == 0)

            if (data_iter_step + 1) % accum_iter == 0:
                optimizer.zero_grad()

            torch.cuda.synchronize()

            metric_logger.update(loss=loss_value)

            lr = optimizer.param_groups[0]["lr"]
            metric_logger.update(lr=lr)

            loss_value_reduce = misc.all_reduce_mean(loss_value)

            if log_writer is not None :
                """ We use epoch_1000x as the x-axis in tensorboard.
                This calibrates different curves when batch size changes.
                """
                epoch_1000x = int(
                    (data_iter_step / len(train_loader) + epoch) * 1000)
                log_writer.add_scalar('train_loss', loss_value_reduce, epoch_1000x)
                log_writer.add_scalar('lr', lr, epoch_1000x)

        # gather the stats from all processes
        metric_logger.synchronize_between_processes()
        print("Averaged stats:", metric_logger)
        train_stats = {k: meter.global_avg for k, meter in metric_logger.meters.items()}
        



        

        #----------------------------验证-----------------------------------------------
        #每4个epoch进行一次验证
        if(epoch%4==0):
            with torch.no_grad(): #表示在验证的时候不需要梯度计算
                model.eval()
                dice_score = 0.
                iou_score = 0.
                for data in valid_loader:
                    valid_image = data["image"]
                    valid_target = data["mask"]

                    valid_image = valid_image.to(device, non_blocking=True)
                    valid_target = valid_target.to(device, non_blocking=True)

                    _,out = model(valid_image, valid_target) #[N,196,256]
                    out = model.unpatchify(out) #[N,1,224,224]
                    dice_score += dice_coef_metric(out.cpu(), valid_target.cpu())
                    iou_score += jaccard_coef_metric(out.cpu(), valid_target.cpu())
                
                dice_score /= len(valid_loader)
                iou_score /= len(valid_loader)
                print("epoch=", epoch,
                    "dice_score=", dice_score,
                    "iou_score=", iou_score)

                print("------------------------------------------------------------------")
                log_writer.add_scalar(tag="dice_scalar", scalar_value=dice_score, global_step=epoch)
                log_writer.add_scalar(tag="iou_scalar", scalar_value=iou_score, global_step=epoch)
                #原作者的save方法,封装更多内容 
                misc.save_model(args=args, model=model, model_without_ddp=model, optimizer=optimizer,
                loss_scaler=loss_scaler, epoch=epoch)
                #torch官方save方法
                torch.save(model.state_dict(), '/data/zhanghao/skull_project/MODEL/cangku_cc359_ViT/' +
                                    str(epoch) + 'ViT' + str(dice_score) + '.pth')
                

            #早停
            if epoch > 20:
                min = 999
                for i in range(int(epoch/4 - 5) , int(epoch/4 - 1) ):
                    if dice_list[i] < min:
                        min = dice_list[i]
                if dice_score < min:
                    lr /= 10
                    print(lr)
                    if lr < 1e-6:
                        break

            dice_list.append(dice_score)#依次放入epoch为0 4 8 12 16 20 24....

        log_stats = {**{f'train_{k}': v for k, v in train_stats.items()},
                     'epoch': epoch, }

        if args.output_dir and misc.is_main_process():
            if log_writer is not None:
                log_writer.flush()
            with open(os.path.join(args.output_dir, "log.txt"), mode="a", encoding="utf-8") as f:
                f.write(json.dumps(log_stats) + "\n")

    total_time = time.time() - start_time
    total_time_str = str(datetime.timedelta(seconds=int(total_time)))
    print('Training time {}'.format(total_time_str))

# %%
args = get_args_parser()
args = args.parse_args(args=[])
if args.output_dir:
    Path(args.output_dir).mkdir(parents=True, exist_ok=True)
main(args)
# Out:
# [18:59:39.105961] Namespace(batch_size=64,
# epochs=1000,
# accum_iter=1,
# model='mae_vit_base_patch16',
# input_size=224,
# mask_ratio=0.75,
# norm_pix_loss=False,
# weight_decay=0.0005,
# lr=0.0001,
# blr=0.0001,
# min_lr=0.0,
# warmup_epochs=40,
# data_path='/datasets01/imagenet_full_size/061417/',
# output_dir='./my_supervised_seg_ViT_earlystop_dice_lossforpatch',
# log_dir='./my_supervised_seg_ViT_earlystop_dice_lossforpatch',
# device='cuda:3',
# seed=0,
# resume='',
# start_epoch=0,
# num_workers=10,
# pin_mem=True,
# world_size=1,
# local_rank=-1,
# dist_on_itp=False,
# dist_url='env://')
# [18:59:44.448606] Model = SegViT2D(
#   (patch_embed): PatchEmbed(
#     (proj): Conv2d(1, 768, kernel_size=(16, 16), stride=(16, 16))
#     (norm): Identity()
#   )
#   (blocks): ModuleList(
#     (0): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (4): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (5): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (6): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (7): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (8): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (9): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (10): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (11): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   (decoder_embed): Linear(in_features=768, out_features=512, bias=True)
#   (decoder_blocks): ModuleList(
#     (0): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (4): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (5): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (6): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (7): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (decoder_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#   (decoder_pred): Linear(in_features=512, out_features=256, bias=True)
# )
# [18:59:44.448846] actual lr: 0.0001
# [18:59:44.448878] accumulate grad iterations: 1
# [18:59:44.450882] effective batch size: 64
# [18:59:44.452200] 查看optimizer =  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.95)
#     eps: 1e-08
#     lr: 0.0001
#     weight_decay: 0.0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.95)
#     eps: 1e-08
#     lr: 0.0001
#     weight_decay: 0.0005
# )
# [18:59:44.452342] Start training for 1000 epochs
# [18:59:44.455103] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [19:11:30.233641] Averaged stats: lr: 0.000002  loss: 0.4464 (0.5968)
# [19:15:09.598726] epoch= 0 dice_score= 0.16549070179462433 iou_score= 0.09020978957414627
# [19:15:09.599115] ------------------------------------------------------------------
# [19:15:17.928130] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [19:20:46.000181] Averaged stats: lr: 0.000005  loss: 0.2398 (0.3434)
# [19:20:46.006492] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [19:26:09.159393] Averaged stats: lr: 0.000007  loss: 0.1086 (0.1643)
# [19:26:09.164823] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [19:31:31.747430] Averaged stats: lr: 0.000010  loss: 0.0706 (0.0867)
# [19:31:31.752915] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [19:36:57.729440] Averaged stats: lr: 0.000012  loss: 0.0519 (0.0595)
# [19:39:13.495876] epoch= 4 dice_score= 0.6606060862541199 iou_score= 0.49321267008781433
# [19:39:13.496353] ------------------------------------------------------------------
# [19:39:16.008344] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [19:44:39.646441] Averaged stats: lr: 0.000015  loss: 0.0395 (0.0447)
# [19:44:39.651839] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [19:50:07.368946] Averaged stats: lr: 0.000017  loss: 0.0337 (0.0369)
# [19:50:07.374088] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [19:55:31.744397] Averaged stats: lr: 0.000020  loss: 0.0310 (0.0322)
# [19:55:31.749354] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [20:00:53.371894] Averaged stats: lr: 0.000022  loss: 0.0268 (0.0289)
# [20:03:10.086189] epoch= 8 dice_score= 0.7968337535858154 iou_score= 0.6622806787490845
# [20:03:10.087092] ------------------------------------------------------------------
# [20:03:12.626527] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [20:08:37.370967] Averaged stats: lr: 0.000025  loss: 0.0256 (0.0263)
# [20:08:37.381893] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [20:14:04.261643] Averaged stats: lr: 0.000027  loss: 0.0235 (0.0243)
# [20:14:04.266932] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [20:19:30.484758] Averaged stats: lr: 0.000030  loss: 0.0219 (0.0227)
# [20:19:30.491750] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [20:24:57.592104] Averaged stats: lr: 0.000032  loss: 0.0204 (0.0214)
# [20:27:14.568905] epoch= 12 dice_score= 0.8010139465332031 iou_score= 0.6680760979652405
# [20:27:14.569302] ------------------------------------------------------------------
# [20:27:17.104277] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [20:32:43.292919] Averaged stats: lr: 0.000035  loss: 0.0197 (0.0205)
# [20:32:43.297564] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [20:38:13.628994] Averaged stats: lr: 0.000037  loss: 0.0192 (0.0194)
# [20:38:13.634281] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [20:43:40.909800] Averaged stats: lr: 0.000040  loss: 0.0178 (0.0186)
# [20:43:40.914339] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [20:49:08.020113] Averaged stats: lr: 0.000042  loss: 0.0177 (0.0179)
# [20:51:28.810148] epoch= 16 dice_score= 0.8089330196380615 iou_score= 0.6791666746139526
# [20:51:28.810457] ------------------------------------------------------------------
# [20:51:31.308228] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [20:57:01.684159] Averaged stats: lr: 0.000045  loss: 0.0166 (0.0172)
# [20:57:01.688596] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [21:02:26.026857] Averaged stats: lr: 0.000047  loss: 0.0166 (0.0165)
# [21:02:26.032479] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [21:07:49.841804] Averaged stats: lr: 0.000050  loss: 0.0155 (0.0160)
# [21:07:49.846605] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [21:13:15.703988] Averaged stats: lr: 0.000052  loss: 0.0150 (0.0154)
# [21:15:31.896440] epoch= 20 dice_score= 0.8402777910232544 iou_score= 0.7245509028434753
# [21:15:31.896791] ------------------------------------------------------------------
# [21:15:40.253257] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [21:21:02.213903] Averaged stats: lr: 0.000055  loss: 0.0149 (0.0149)
# [21:21:02.218602] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [21:26:29.363828] Averaged stats: lr: 0.000057  loss: 0.0140 (0.0145)
# [21:26:29.369224] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [21:31:57.012377] Averaged stats: lr: 0.000060  loss: 0.0144 (0.0141)
# [21:31:57.017393] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [21:37:23.624934] Averaged stats: lr: 0.000062  loss: 0.0135 (0.0136)
# [21:39:38.684298] epoch= 24 dice_score= 0.8188976645469666 iou_score= 0.6933333277702332
# [21:39:38.684613] ------------------------------------------------------------------
# [21:39:41.163817] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [21:45:07.625800] Averaged stats: lr: 0.000065  loss: 0.0132 (0.0132)
# [21:45:07.630546] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [21:50:31.376190] Averaged stats: lr: 0.000067  loss: 0.0128 (0.0128)
# [21:50:31.381102] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [21:55:59.095273] Averaged stats: lr: 0.000070  loss: 0.0120 (0.0123)
# [21:55:59.100461] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [22:01:25.047588] Averaged stats: lr: 0.000072  loss: 0.0125 (0.0120)
# [22:04:00.378038] epoch= 28 dice_score= 0.8062418699264526 iou_score= 0.6753812432289124
# [22:04:00.379232] ------------------------------------------------------------------
# [22:04:02.852687] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [22:09:29.078281] Averaged stats: lr: 0.000075  loss: 0.0116 (0.0117)
# [22:09:29.085404] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [22:14:58.153460] Averaged stats: lr: 0.000077  loss: 0.0111 (0.0113)
# [22:14:58.157952] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [22:20:23.225330] Averaged stats: lr: 0.000080  loss: 0.0109 (0.0110)
# [22:20:23.231053] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [22:25:49.738283] Averaged stats: lr: 0.000082  loss: 0.0105 (0.0106)
# [22:28:05.971409] epoch= 32 dice_score= 0.8759124279022217 iou_score= 0.7792207598686218
# [22:28:05.971800] ------------------------------------------------------------------
# [22:28:08.487629] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [22:33:31.801543] Averaged stats: lr: 0.000085  loss: 0.0102 (0.0104)
# [22:33:31.807033] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [22:38:58.134318] Averaged stats: lr: 0.000087  loss: 0.0101 (0.0101)
# [22:38:58.139900] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [22:44:28.801898] Averaged stats: lr: 0.000090  loss: 0.0097 (0.0098)
# [22:44:28.806316] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [22:49:55.057837] Averaged stats: lr: 0.000092  loss: 0.0096 (0.0095)
# [22:52:16.296657] epoch= 36 dice_score= 0.8766788840293884 iou_score= 0.780434787273407
# [22:52:16.297019] ------------------------------------------------------------------
# [22:52:18.883363] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [22:57:41.343443] Averaged stats: lr: 0.000095  loss: 0.0096 (0.0093)
# [22:57:41.347827] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [23:03:10.080491] Averaged stats: lr: 0.000097  loss: 0.0090 (0.0091)
# [23:03:10.085761] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [23:08:37.245589] Averaged stats: lr: 0.000100  loss: 0.0092 (0.0089)
# [23:08:37.250785] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [23:14:05.477207] Averaged stats: lr: 0.000100  loss: 0.0089 (0.0086)
# [23:16:33.526633] epoch= 40 dice_score= 0.885644793510437 iou_score= 0.7947598099708557
# [23:16:33.526948] ------------------------------------------------------------------
# [23:16:41.726441] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [23:22:09.128216] Averaged stats: lr: 0.000100  loss: 0.0084 (0.0084)
# [23:22:09.133918] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [23:27:35.784123] Averaged stats: lr: 0.000100  loss: 0.0080 (0.0082)
# [23:27:35.789704] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [23:33:03.044304] Averaged stats: lr: 0.000100  loss: 0.0080 (0.0080)
# [23:33:03.048830] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [23:38:35.449206] Averaged stats: lr: 0.000100  loss: 0.0075 (0.0077)
# [23:40:53.668793] epoch= 44 dice_score= 0.8861076235771179 iou_score= 0.7955056428909302
# [23:40:53.669121] ------------------------------------------------------------------
# [23:40:56.135833] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [23:46:19.141565] Averaged stats: lr: 0.000100  loss: 0.0075 (0.0075)
# [23:46:19.145895] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [23:51:42.668835] Averaged stats: lr: 0.000100  loss: 0.0074 (0.0072)
# [23:51:42.674874] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [23:57:11.902829] Averaged stats: lr: 0.000100  loss: 0.0070 (0.0070)
# [23:57:11.907990] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [00:02:38.546228] Averaged stats: lr: 0.000100  loss: 0.0067 (0.0068)
# [00:04:57.623612] epoch= 48 dice_score= 0.8953770995140076 iou_score= 0.8105726838111877
# [00:04:57.624903] ------------------------------------------------------------------
# [00:05:00.264433] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [00:10:25.464635] Averaged stats: lr: 0.000100  loss: 0.0068 (0.0066)
# [00:10:25.471683] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [00:15:48.246980] Averaged stats: lr: 0.000100  loss: 0.0064 (0.0064)
# [00:15:48.252541] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [00:21:14.761508] Averaged stats: lr: 0.000100  loss: 0.0063 (0.0063)
# [00:21:14.767516] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [00:26:40.108536] Averaged stats: lr: 0.000100  loss: 0.0061 (0.0061)
# [00:29:06.597250] epoch= 52 dice_score= 0.9054373502731323 iou_score= 0.8272138237953186
# [00:29:06.598156] ------------------------------------------------------------------
# [00:29:09.088464] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [00:34:41.272303] Averaged stats: lr: 0.000100  loss: 0.0058 (0.0059)
# [00:34:41.278732] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [00:40:08.756426] Averaged stats: lr: 0.000100  loss: 0.0057 (0.0058)
# [00:40:08.761560] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [00:45:38.167526] Averaged stats: lr: 0.000100  loss: 0.0057 (0.0056)
# [00:45:38.171982] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [00:51:00.747163] Averaged stats: lr: 0.000100  loss: 0.0055 (0.0055)
# [00:53:20.368863] epoch= 56 dice_score= 0.9033816456794739 iou_score= 0.8237885236740112
# [00:53:20.370038] ------------------------------------------------------------------
# [00:53:22.850444] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [00:58:45.639981] Averaged stats: lr: 0.000100  loss: 0.0055 (0.0054)
# [00:58:45.645367] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [01:04:08.907227] Averaged stats: lr: 0.000100  loss: 0.0053 (0.0052)
# [01:04:08.911842] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [01:09:37.836648] Averaged stats: lr: 0.000100  loss: 0.0052 (0.0051)
# [01:09:37.842192] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [01:15:09.392298] Averaged stats: lr: 0.000100  loss: 0.0051 (0.0050)
# [01:17:59.302327] epoch= 60 dice_score= 0.9097303748130798 iou_score= 0.8344085812568665
# [01:17:59.302668] ------------------------------------------------------------------
# [01:18:01.790651] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [01:23:22.918656] Averaged stats: lr: 0.000100  loss: 0.0050 (0.0049)
# [01:23:22.923464] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [01:28:48.881012] Averaged stats: lr: 0.000100  loss: 0.0048 (0.0048)
# [01:28:48.887555] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [01:34:12.505451] Averaged stats: lr: 0.000100  loss: 0.0047 (0.0047)
# [01:34:12.511582] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [01:39:43.266131] Averaged stats: lr: 0.000100  loss: 0.0047 (0.0046)
# [01:42:21.580595] epoch= 64 dice_score= 0.9097387194633484 iou_score= 0.8344226479530334
# [01:42:21.580925] ------------------------------------------------------------------
# [01:42:24.108140] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [01:47:46.691927] Averaged stats: lr: 0.000100  loss: 0.0045 (0.0045)
# [01:47:46.697238] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [01:53:15.166003] Averaged stats: lr: 0.000100  loss: 0.0044 (0.0044)
# [01:53:15.171507] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [01:58:40.957573] Averaged stats: lr: 0.000100  loss: 0.0044 (0.0043)
# [01:58:40.962603] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [02:04:02.550804] Averaged stats: lr: 0.000100  loss: 0.0043 (0.0042)
# [02:06:28.137118] epoch= 68 dice_score= 0.8795944452285767 iou_score= 0.7850678563117981
# [02:06:28.137465] ------------------------------------------------------------------
# [02:06:30.607872] 9.977503051588605e-06
# [02:06:30.612249] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [02:11:54.747309] Averaged stats: lr: 0.000100  loss: 0.0043 (0.0042)
# [02:11:54.752697] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [02:17:24.188817] Averaged stats: lr: 0.000100  loss: 0.0041 (0.0041)
# [02:17:24.194148] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [02:22:50.650218] Averaged stats: lr: 0.000100  loss: 0.0040 (0.0040)
# [02:22:50.655624] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [02:28:12.669511] Averaged stats: lr: 0.000100  loss: 0.0039 (0.0040)
# [02:30:28.017264] epoch= 72 dice_score= 0.922363817691803 iou_score= 0.8559139966964722
# [02:30:28.017638] ------------------------------------------------------------------
# [02:30:30.520338] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [02:35:53.442129] Averaged stats: lr: 0.000100  loss: 0.0040 (0.0039)
# [02:35:53.446457] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [02:41:17.449508] Averaged stats: lr: 0.000100  loss: 0.0039 (0.0038)
# [02:41:17.453775] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [02:46:47.094578] Averaged stats: lr: 0.000100  loss: 0.0038 (0.0037)
# [02:46:47.100384] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [02:52:16.406709] Averaged stats: lr: 0.000100  loss: 0.0037 (0.0037)
# [02:54:41.153256] epoch= 76 dice_score= 0.9318996667861938 iou_score= 0.8724831938743591
# [02:54:41.153648] ------------------------------------------------------------------
# [02:54:43.757705] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [03:00:07.054172] Averaged stats: lr: 0.000100  loss: 0.0036 (0.0036)
# [03:00:07.059826] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [03:05:32.190273] Averaged stats: lr: 0.000100  loss: 0.0036 (0.0035)
# [03:05:32.195238] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [03:10:55.145959] Averaged stats: lr: 0.000100  loss: 0.0035 (0.0035)
# [03:10:55.151671] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [03:16:22.262291] Averaged stats: lr: 0.000100  loss: 0.0035 (0.0034)
# [03:18:40.234762] epoch= 80 dice_score= 0.9256594777107239 iou_score= 0.8616071343421936
# [03:18:40.235136] ------------------------------------------------------------------
# [03:18:43.115070] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [03:24:10.493989] Averaged stats: lr: 0.000100  loss: 0.0033 (0.0034)
# [03:24:10.499441] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [03:29:35.475414] Averaged stats: lr: 0.000100  loss: 0.0033 (0.0033)
# [03:29:35.482503] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [03:35:01.252810] Averaged stats: lr: 0.000099  loss: 0.0033 (0.0032)
# [03:35:01.258447] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [03:40:25.775738] Averaged stats: lr: 0.000099  loss: 0.0032 (0.0032)
# [03:42:45.148844] epoch= 84 dice_score= 0.9317365288734436 iou_score= 0.8721973299980164
# [03:42:45.149947] ------------------------------------------------------------------
# [03:42:47.693725] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [03:48:10.952481] Averaged stats: lr: 0.000099  loss: 0.0031 (0.0031)
# [03:48:10.957949] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [03:53:33.717176] Averaged stats: lr: 0.000099  loss: 0.0031 (0.0031)
# [03:53:33.721458] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [03:58:57.943249] Averaged stats: lr: 0.000099  loss: 0.0031 (0.0030)
# [03:58:57.948788] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [04:04:21.798029] Averaged stats: lr: 0.000099  loss: 0.0029 (0.0030)
# [04:06:43.819873] epoch= 88 dice_score= 0.9245283007621765 iou_score= 0.859649121761322
# [04:06:43.820245] ------------------------------------------------------------------
# [04:06:46.363023] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [04:12:08.814834] Averaged stats: lr: 0.000099  loss: 0.0030 (0.0029)
# [04:12:08.820317] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [04:17:32.026010] Averaged stats: lr: 0.000099  loss: 0.0028 (0.0029)
# [04:17:32.030459] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [04:22:55.825744] Averaged stats: lr: 0.000099  loss: 0.0028 (0.0028)
# [04:22:55.830325] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [04:28:19.437153] Averaged stats: lr: 0.000099  loss: 0.0029 (0.0028)
# [04:30:38.250327] epoch= 92 dice_score= 0.9208282828330994 iou_score= 0.8532731533050537
# [04:30:38.250681] ------------------------------------------------------------------
# [04:30:40.874039] 9.924987061356182e-06
# [04:30:40.878462] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [04:36:03.227325] Averaged stats: lr: 0.000099  loss: 0.0028 (0.0027)
# [04:36:03.232379] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [04:41:28.844793] Averaged stats: lr: 0.000099  loss: 0.0027 (0.0027)
# [04:41:28.849671] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [04:46:53.052451] Averaged stats: lr: 0.000099  loss: 0.0027 (0.0026)
# [04:46:53.058385] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [04:52:18.330397] Averaged stats: lr: 0.000099  loss: 0.0026 (0.0026)
# [04:54:38.856177] epoch= 96 dice_score= 0.9379475116729736 iou_score= 0.8831460475921631
# [04:54:38.857213] ------------------------------------------------------------------
# [04:54:41.437061] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [05:00:05.370365] Averaged stats: lr: 0.000099  loss: 0.0026 (0.0026)
# [05:00:05.375571] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [05:05:30.407030] Averaged stats: lr: 0.000099  loss: 0.0025 (0.0025)
# [05:05:30.412599] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [05:10:55.222509] Averaged stats: lr: 0.000099  loss: 0.0024 (0.0025)
# [05:10:55.227863] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [05:16:22.428834] Averaged stats: lr: 0.000099  loss: 0.0025 (0.0024)
# [05:18:42.837458] epoch= 100 dice_score= 0.9375 iou_score= 0.8823529481887817
# [05:18:42.838391] ------------------------------------------------------------------
# [05:18:45.379619] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [05:24:09.079659] Averaged stats: lr: 0.000099  loss: 0.0024 (0.0024)
# [05:24:09.085391] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [05:29:32.215675] Averaged stats: lr: 0.000099  loss: 0.0024 (0.0023)
# [05:29:32.221395] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [05:34:54.162334] Averaged stats: lr: 0.000099  loss: 0.0023 (0.0023)
# [05:34:54.168266] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [05:40:19.168775] Averaged stats: lr: 0.000099  loss: 0.0024 (0.0023)
# [05:42:39.578431] epoch= 104 dice_score= 0.9424460530281067 iou_score= 0.8911564350128174
# [05:42:39.578747] ------------------------------------------------------------------
# [05:42:42.110091] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [05:48:05.094966] Averaged stats: lr: 0.000099  loss: 0.0022 (0.0023)
# [05:48:05.100367] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [05:53:28.143814] Averaged stats: lr: 0.000099  loss: 0.0022 (0.0022)
# [05:53:28.149431] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [05:58:54.501062] Averaged stats: lr: 0.000099  loss: 0.0021 (0.0022)
# [05:58:54.506141] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [06:04:18.162419] Averaged stats: lr: 0.000099  loss: 0.0022 (0.0022)
# [06:06:35.852596] epoch= 108 dice_score= 0.9328536987304688 iou_score= 0.8741573095321655
# [06:06:35.852932] ------------------------------------------------------------------
# [06:06:38.349529] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [06:12:00.495297] Averaged stats: lr: 0.000099  loss: 0.0021 (0.0021)
# [06:12:00.500303] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [06:17:28.010620] Averaged stats: lr: 0.000099  loss: 0.0020 (0.0021)
# [06:17:28.016086] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [06:22:52.883075] Averaged stats: lr: 0.000099  loss: 0.0020 (0.0021)
# [06:22:52.889196] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [06:28:21.504360] Averaged stats: lr: 0.000099  loss: 0.0021 (0.0020)
# [06:30:40.320928] epoch= 112 dice_score= 0.9370459914207458 iou_score= 0.8815490007400513
# [06:30:40.322493] ------------------------------------------------------------------
# [06:30:43.178800] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [06:36:10.564968] Averaged stats: lr: 0.000099  loss: 0.0020 (0.0020)
# [06:36:10.570969] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [06:41:38.285118] Averaged stats: lr: 0.000099  loss: 0.0020 (0.0020)
# [06:41:38.290643] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [06:47:03.693963] Averaged stats: lr: 0.000098  loss: 0.0020 (0.0019)
# [06:47:03.699340] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [06:52:29.512795] Averaged stats: lr: 0.000098  loss: 0.0020 (0.0019)
# [06:54:48.446880] epoch= 116 dice_score= 0.9314079284667969 iou_score= 0.8716216087341309
# [06:54:48.448319] ------------------------------------------------------------------
# [06:54:51.319783] 9.84210688816611e-06
# [06:54:51.324381] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [07:00:16.425004] Averaged stats: lr: 0.000098  loss: 0.0019 (0.0019)
# [07:00:16.430681] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [07:05:42.713979] Averaged stats: lr: 0.000098  loss: 0.0020 (0.0019)
# [07:05:42.719310] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [07:11:07.758981] Averaged stats: lr: 0.000098  loss: 0.0018 (0.0018)
# [07:11:07.763876] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [07:16:34.481989] Averaged stats: lr: 0.000098  loss: 0.0018 (0.0018)
# [07:18:54.689992] epoch= 120 dice_score= 0.9462365508079529 iou_score= 0.8979591727256775
# [07:18:54.691291] ------------------------------------------------------------------
# [07:18:57.183644] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [07:24:20.482329] Averaged stats: lr: 0.000098  loss: 0.0017 (0.0018)
# [07:24:20.487213] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [07:29:47.342769] Averaged stats: lr: 0.000098  loss: 0.0017 (0.0018)
# [07:29:47.348568] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [07:35:14.731893] Averaged stats: lr: 0.000098  loss: 0.0018 (0.0017)
# [07:35:14.737278] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [07:40:41.859121] Averaged stats: lr: 0.000098  loss: 0.0017 (0.0017)
# [07:43:03.277688] epoch= 124 dice_score= 0.942168653011322 iou_score= 0.8906605839729309
# [07:43:03.278870] ------------------------------------------------------------------
# [07:43:06.205694] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [07:48:30.534045] Averaged stats: lr: 0.000098  loss: 0.0017 (0.0017)
# [07:48:30.538999] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [07:53:53.628632] Averaged stats: lr: 0.000098  loss: 0.0017 (0.0017)
# [07:53:53.634038] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [07:59:17.852369] Averaged stats: lr: 0.000098  loss: 0.0017 (0.0016)
# [07:59:17.857799] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [08:04:43.101518] Averaged stats: lr: 0.000098  loss: 0.0017 (0.0016)
# [08:07:02.847592] epoch= 128 dice_score= 0.9366785883903503 iou_score= 0.8808988928794861
# [08:07:02.848797] ------------------------------------------------------------------
# [08:07:05.349166] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [08:12:27.505529] Averaged stats: lr: 0.000098  loss: 0.0016 (0.0016)
# [08:12:27.510481] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [08:17:50.211930] Averaged stats: lr: 0.000098  loss: 0.0016 (0.0016)
# [08:17:50.217665] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [08:23:12.901922] Averaged stats: lr: 0.000098  loss: 0.0016 (0.0015)
# [08:23:12.906628] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [08:28:38.462290] Averaged stats: lr: 0.000098  loss: 0.0015 (0.0015)
# [08:30:59.233069] epoch= 132 dice_score= 0.9462365508079529 iou_score= 0.8979591727256775
# [08:30:59.233408] ------------------------------------------------------------------
# [08:31:01.717838] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [08:36:24.748548] Averaged stats: lr: 0.000098  loss: 0.0015 (0.0015)
# [08:36:24.753146] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [08:41:48.634967] Averaged stats: lr: 0.000098  loss: 0.0015 (0.0015)
# [08:41:48.639730] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [08:47:10.019734] Averaged stats: lr: 0.000098  loss: 0.0015 (0.0015)
# [08:47:10.025406] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [08:52:33.916881] Averaged stats: lr: 0.000098  loss: 0.0014 (0.0014)
# [08:54:54.501961] epoch= 136 dice_score= 0.9442467093467712 iou_score= 0.8943819999694824
# [08:54:54.502322] ------------------------------------------------------------------
# [08:54:56.997552] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:00:20.500300] Averaged stats: lr: 0.000097  loss: 0.0014 (0.0014)
# [09:00:20.505696] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:05:45.237740] Averaged stats: lr: 0.000097  loss: 0.0013 (0.0014)
# [09:05:45.242149] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:11:08.260329] Averaged stats: lr: 0.000097  loss: 0.0013 (0.0014)
# [09:11:08.264750] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:16:33.093666] Averaged stats: lr: 0.000097  loss: 0.0014 (0.0014)
# [09:18:50.951628] epoch= 140 dice_score= 0.9498806595802307 iou_score= 0.9045454263687134
# [09:18:50.951928] ------------------------------------------------------------------
# [09:18:53.467337] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:24:19.763443] Averaged stats: lr: 0.000097  loss: 0.0014 (0.0014)
# [09:24:19.769484] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:29:46.696534] Averaged stats: lr: 0.000097  loss: 0.0014 (0.0014)
# [09:29:46.702180] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:35:14.026969] Averaged stats: lr: 0.000097  loss: 0.0013 (0.0013)
# [09:35:14.032083] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:40:41.692710] Averaged stats: lr: 0.000097  loss: 0.0013 (0.0013)
# [09:43:00.037383] epoch= 144 dice_score= 0.949999988079071 iou_score= 0.9047619104385376
# [09:43:00.038282] ------------------------------------------------------------------
# [09:43:02.731195] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:48:46.091700] Averaged stats: lr: 0.000097  loss: 0.0013 (0.0013)
# [09:48:46.097566] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:54:11.324535] Averaged stats: lr: 0.000097  loss: 0.0013 (0.0013)
# [09:54:11.330940] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:59:40.984345] Averaged stats: lr: 0.000097  loss: 0.0013 (0.0013)
# [09:59:40.989808] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:05:08.334668] Averaged stats: lr: 0.000097  loss: 0.0013 (0.0013)
# [10:07:27.853007] epoch= 148 dice_score= 0.9497607946395874 iou_score= 0.9043279886245728
# [10:07:27.854167] ------------------------------------------------------------------
# [10:07:30.508213] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:13:16.611686] Averaged stats: lr: 0.000097  loss: 0.0013 (0.0013)
# [10:13:16.616500] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:18:41.471188] Averaged stats: lr: 0.000097  loss: 0.0012 (0.0012)
# [10:18:41.476036] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:24:08.472665] Averaged stats: lr: 0.000097  loss: 0.0012 (0.0012)
# [10:24:08.477730] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:29:34.376328] Averaged stats: lr: 0.000097  loss: 0.0013 (0.0012)
# [10:31:54.267042] epoch= 152 dice_score= 0.9471153616905212 iou_score= 0.8995434045791626
# [10:31:54.267363] ------------------------------------------------------------------
# [10:31:56.929565] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:37:24.157983] Averaged stats: lr: 0.000097  loss: 0.0012 (0.0012)
# [10:37:24.164047] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:42:53.868218] Averaged stats: lr: 0.000097  loss: 0.0012 (0.0012)
# ...
# [08:57:27.073780] Averaged stats: lr: 0.000037  loss: 0.0004 (0.0004)
# [08:57:27.079029] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:02:57.230061] Averaged stats: lr: 0.000036  loss: 0.0004 (0.0004)
# [09:02:57.235803] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:08:23.474538] Averaged stats: lr: 0.000036  loss: 0.0004 (0.0004)
# [09:10:39.106878] epoch= 604 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [09:10:39.107223] ------------------------------------------------------------------
# [09:10:41.665250] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:16:03.031572] Averaged stats: lr: 0.000036  loss: 0.0004 (0.0004)
# [09:16:03.036289] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:21:30.532722] Averaged stats: lr: 0.000036  loss: 0.0004 (0.0004)
# [09:21:30.538809] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:26:58.262848] Averaged stats: lr: 0.000036  loss: 0.0004 (0.0004)
# [09:26:58.269877] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:32:20.855895] Averaged stats: lr: 0.000036  loss: 0.0004 (0.0004)
# [09:34:37.306665] epoch= 608 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [09:34:37.306971] ------------------------------------------------------------------
# [09:34:39.891909] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:40:09.175119] Averaged stats: lr: 0.000035  loss: 0.0004 (0.0004)
# [09:40:09.180403] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:45:37.819940] Averaged stats: lr: 0.000035  loss: 0.0004 (0.0004)
# [09:45:37.824669] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:51:00.782710] Averaged stats: lr: 0.000035  loss: 0.0004 (0.0004)
# [09:51:00.787855] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [09:56:26.931045] Averaged stats: lr: 0.000035  loss: 0.0004 (0.0004)
# [09:58:44.188544] epoch= 612 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [09:58:44.189481] ------------------------------------------------------------------
# [09:58:46.766366] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:04:17.790341] Averaged stats: lr: 0.000035  loss: 0.0004 (0.0004)
# [10:04:17.794808] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:09:42.779948] Averaged stats: lr: 0.000035  loss: 0.0004 (0.0004)
# [10:09:42.786056] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:15:11.107243] Averaged stats: lr: 0.000035  loss: 0.0004 (0.0004)
# [10:15:11.112430] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:20:34.412084] Averaged stats: lr: 0.000034  loss: 0.0004 (0.0004)
# [10:22:58.393405] epoch= 616 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [10:22:58.393744] ------------------------------------------------------------------
# [10:23:00.869400] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:28:30.018630] Averaged stats: lr: 0.000034  loss: 0.0004 (0.0004)
# [10:28:30.023935] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:34:00.481814] Averaged stats: lr: 0.000034  loss: 0.0004 (0.0004)
# [10:34:00.490905] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:39:26.764482] Averaged stats: lr: 0.000034  loss: 0.0004 (0.0004)
# [10:39:26.770434] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:44:50.816703] Averaged stats: lr: 0.000034  loss: 0.0004 (0.0004)
# [10:47:24.865008] epoch= 620 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [10:47:24.866127] ------------------------------------------------------------------
# [10:47:27.476311] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:52:56.466093] Averaged stats: lr: 0.000034  loss: 0.0004 (0.0004)
# [10:52:56.470814] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [10:58:29.058368] Averaged stats: lr: 0.000033  loss: 0.0004 (0.0004)
# [10:58:29.065962] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [11:04:02.421884] Averaged stats: lr: 0.000033  loss: 0.0004 (0.0004)
# [11:04:02.429167] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [11:09:33.728160] Averaged stats: lr: 0.000033  loss: 0.0004 (0.0004)
# [11:11:54.227934] epoch= 624 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [11:11:54.228279] ------------------------------------------------------------------
# [11:11:56.725258] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [11:17:27.548069] Averaged stats: lr: 0.000033  loss: 0.0004 (0.0004)
# [11:17:27.552507] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [11:22:59.211729] Averaged stats: lr: 0.000033  loss: 0.0004 (0.0004)
# [11:22:59.216286] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [11:28:28.571288] Averaged stats: lr: 0.000033  loss: 0.0004 (0.0004)
# [11:28:28.576127] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [11:33:58.584244] Averaged stats: lr: 0.000033  loss: 0.0003 (0.0004)
# [11:36:28.292468] epoch= 628 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [11:36:28.293468] ------------------------------------------------------------------
# [11:36:30.770664] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [11:41:58.587215] Averaged stats: lr: 0.000032  loss: 0.0004 (0.0004)
# [11:41:58.592660] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [11:47:27.731956] Averaged stats: lr: 0.000032  loss: 0.0004 (0.0004)
# [11:47:27.738269] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [11:53:00.955444] Averaged stats: lr: 0.000032  loss: 0.0004 (0.0004)
# [11:53:00.960384] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [11:58:38.683178] Averaged stats: lr: 0.000032  loss: 0.0004 (0.0004)
# [12:01:08.597134] epoch= 632 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [12:01:08.597493] ------------------------------------------------------------------
# [12:01:11.263666] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [12:06:46.984728] Averaged stats: lr: 0.000032  loss: 0.0004 (0.0004)
# [12:06:46.991337] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [12:12:24.070934] Averaged stats: lr: 0.000032  loss: 0.0004 (0.0004)
# [12:12:24.075836] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [12:18:02.785272] Averaged stats: lr: 0.000031  loss: 0.0004 (0.0004)
# [12:18:02.789436] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [12:23:41.694362] Averaged stats: lr: 0.000031  loss: 0.0004 (0.0004)
# [12:26:06.169269] epoch= 636 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [12:26:06.169605] ------------------------------------------------------------------
# [12:26:08.810894] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [12:31:47.108181] Averaged stats: lr: 0.000031  loss: 0.0004 (0.0004)
# [12:31:47.112765] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [12:37:23.099933] Averaged stats: lr: 0.000031  loss: 0.0004 (0.0004)
# [12:37:23.104783] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [12:43:00.377219] Averaged stats: lr: 0.000031  loss: 0.0004 (0.0004)
# [12:43:00.382859] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [12:48:35.635403] Averaged stats: lr: 0.000031  loss: 0.0004 (0.0004)
# [12:51:04.432415] epoch= 640 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [12:51:04.432730] ------------------------------------------------------------------
# [12:51:07.185922] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [12:56:54.352847] Averaged stats: lr: 0.000031  loss: 0.0004 (0.0004)
# [12:56:54.357579] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [13:03:02.626703] Averaged stats: lr: 0.000030  loss: 0.0004 (0.0004)
# [13:03:02.638125] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [13:09:17.542557] Averaged stats: lr: 0.000030  loss: 0.0004 (0.0004)
# [13:09:17.547401] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [13:15:15.872486] Averaged stats: lr: 0.000030  loss: 0.0004 (0.0004)
# [13:18:18.403220] epoch= 644 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [13:18:18.404510] ------------------------------------------------------------------
# [13:18:21.140469] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [13:24:14.812607] Averaged stats: lr: 0.000030  loss: 0.0004 (0.0004)
# [13:24:14.817666] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [13:30:15.592245] Averaged stats: lr: 0.000030  loss: 0.0004 (0.0004)
# [13:30:15.601668] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [13:36:14.679349] Averaged stats: lr: 0.000030  loss: 0.0004 (0.0004)
# [13:36:14.683892] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [13:42:37.376535] Averaged stats: lr: 0.000030  loss: 0.0004 (0.0004)
# [13:45:46.867383] epoch= 648 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [13:45:46.870718] ------------------------------------------------------------------
# [13:45:49.677684] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [13:51:43.400919] Averaged stats: lr: 0.000029  loss: 0.0004 (0.0004)
# [13:51:43.405468] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [13:57:40.196601] Averaged stats: lr: 0.000029  loss: 0.0004 (0.0004)
# [13:57:40.202264] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [14:03:37.064032] Averaged stats: lr: 0.000029  loss: 0.0004 (0.0004)
# [14:03:37.069501] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [14:09:33.907635] Averaged stats: lr: 0.000029  loss: 0.0004 (0.0004)
# [14:12:36.048564] epoch= 652 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [14:12:36.048943] ------------------------------------------------------------------
# [14:12:38.827635] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [14:18:52.059006] Averaged stats: lr: 0.000029  loss: 0.0004 (0.0004)
# [14:18:52.063645] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [14:24:56.694653] Averaged stats: lr: 0.000029  loss: 0.0004 (0.0004)
# [14:24:56.699461] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [14:30:53.223600] Averaged stats: lr: 0.000028  loss: 0.0004 (0.0004)
# [14:30:53.228276] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [14:36:51.026980] Averaged stats: lr: 0.000028  loss: 0.0004 (0.0004)
# [14:39:57.626581] epoch= 656 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [14:39:57.627925] ------------------------------------------------------------------
# [14:40:00.409258] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [14:45:53.394407] Averaged stats: lr: 0.000028  loss: 0.0004 (0.0004)
# [14:45:53.399636] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [14:51:55.550705] Averaged stats: lr: 0.000028  loss: 0.0003 (0.0004)
# [14:51:55.555706] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [14:58:08.416593] Averaged stats: lr: 0.000028  loss: 0.0004 (0.0004)
# [14:58:08.421658] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [15:04:05.498771] Averaged stats: lr: 0.000028  loss: 0.0004 (0.0004)
# [15:07:04.141931] epoch= 660 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [15:07:04.142886] ------------------------------------------------------------------
# [15:07:07.000290] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [15:13:01.996965] Averaged stats: lr: 0.000028  loss: 0.0004 (0.0004)
# [15:13:02.002767] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [15:19:00.054919] Averaged stats: lr: 0.000027  loss: 0.0004 (0.0004)
# [15:19:00.059281] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [15:24:57.933940] Averaged stats: lr: 0.000027  loss: 0.0004 (0.0004)
# [15:24:57.939455] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [15:31:13.308318] Averaged stats: lr: 0.000027  loss: 0.0004 (0.0004)
# [15:34:30.670869] epoch= 664 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [15:34:30.672226] ------------------------------------------------------------------
# [15:34:33.637848] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [15:40:33.553348] Averaged stats: lr: 0.000027  loss: 0.0003 (0.0004)
# [15:40:33.569798] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [15:46:29.724349] Averaged stats: lr: 0.000027  loss: 0.0004 (0.0004)
# [15:46:29.730013] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [15:52:27.547064] Averaged stats: lr: 0.000027  loss: 0.0004 (0.0004)
# [15:52:27.552804] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [15:58:23.841582] Averaged stats: lr: 0.000027  loss: 0.0004 (0.0004)
# [16:01:34.778949] epoch= 668 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [16:01:34.780294] ------------------------------------------------------------------
# [16:01:37.470442] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [16:07:40.332476] Averaged stats: lr: 0.000026  loss: 0.0004 (0.0004)
# [16:07:40.357233] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [16:13:54.732091] Averaged stats: lr: 0.000026  loss: 0.0004 (0.0004)
# [16:13:54.737015] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [16:19:51.628683] Averaged stats: lr: 0.000026  loss: 0.0004 (0.0004)
# [16:19:51.635022] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [16:25:47.698287] Averaged stats: lr: 0.000026  loss: 0.0004 (0.0004)
# [16:28:51.150442] epoch= 672 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [16:28:51.151936] ------------------------------------------------------------------
# [16:28:53.950727] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [16:34:51.519007] Averaged stats: lr: 0.000026  loss: 0.0004 (0.0004)
# [16:34:51.523663] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [16:40:47.368353] Averaged stats: lr: 0.000026  loss: 0.0004 (0.0004)
# [16:40:47.378767] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [16:47:03.278087] Averaged stats: lr: 0.000026  loss: 0.0004 (0.0004)
# [16:47:03.284803] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [16:53:03.843078] Averaged stats: lr: 0.000025  loss: 0.0004 (0.0004)
# [16:56:10.001853] epoch= 676 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [16:56:10.003310] ------------------------------------------------------------------
# [16:56:12.870462] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [17:02:09.308382] Averaged stats: lr: 0.000025  loss: 0.0004 (0.0004)
# [17:02:09.319790] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [17:08:05.753570] Averaged stats: lr: 0.000025  loss: 0.0004 (0.0004)
# [17:08:05.759279] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [17:14:01.320461] Averaged stats: lr: 0.000025  loss: 0.0004 (0.0004)
# [17:14:01.326293] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [17:20:07.223161] Averaged stats: lr: 0.000025  loss: 0.0004 (0.0004)
# [17:23:16.102669] epoch= 680 dice_score= 0.9704142212867737 iou_score= 0.9425287246704102
# [17:23:16.104035] ------------------------------------------------------------------
# [17:23:18.993777] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# [17:29:30.981203] Averaged stats: lr: 0.000025  loss: 0.0004 (0.0004)
# [17:29:30.985866] log_dir: ./my_supervised_seg_ViT_earlystop_dice_lossforpatch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-4b5dcc0943a6> in <module>
#       3 if args.output_dir:
#       4     Path(args.output_dir).mkdir(parents=True, exist_ok=True)
# ----> 5 main(args)
#
# <ipython-input-4-8dbce5bde002> in main(args)
#      81                 loss, _,  = model(samples, labeles)
#      82
# ---> 83             loss_value = loss.item()
#      84
#      85             if not math.isfinite(loss_value):
#
# KeyboardInterrupt:

# %%
args = get_args_parser()
args = args.parse_args(args=[])
if args.output_dir: 
    print(args.output_dir)

# %%
# 加载测试集
from util.ccdataset import *
train_paths, valid_paths, test_paths = getPathList()
train_loader, valid_loader, test_loader = getDataloader(
    train_paths, valid_paths, test_paths, B=1)
len(test_loader)
# torch.Size([64, 1, 224, 224]) torch.FloatTensor

# %%
from util.diceloss import dice_coeff
import torch.nn as nn
from functools import partial
# model = my_seg_vit.SegViT2D(
#     patch_size=16, embed_dim=768, depth=12, num_heads=12,
#     decoder_embed_dim=512, decoder_depth=8, decoder_num_heads=16,
#     mlp_ratio=4, norm_layer=partial(nn.LayerNorm, eps=1e-6))
model = my_seg_vit.__dict__[args.model](norm_pix_loss=args.norm_pix_loss)

model.load_state_dict(torch.load('./output_dir/checkpoint-20.pth'))
dicecoeff = 0.
for data in test_loader :
    image = data['image']
    mask = data['mask']
    image = image.cuda(1)
    mask = mask.cuda(1)
    _,pred = model(image)
    dicecoeff += dice_coeff(image,pred)
dicecoeff /= len(test_loader)
print("平均dicecoeff=",dicecoeff)

# %%
import torch.nn as nn
import torch.nn.functional as F
class SoftDiceLoss(nn.Module):
    def init(self,weight = None,size_average = True):
        super(SoftDiceLoss,self).init()
        def forward(self,logits,targets):
            num = targets.size(0)
            smooth = 1e-9
            probs = F.sigmoid(logits)
            m1 = probs.view(num,-1)
            m2 = targets.view(num,-1)
            intersection = (m1*m2)
            score = 2.*(intersection.sum(1) + smooth) / (m1.sum(1) + m2.sum(1) + smooth)

            score = 1 - score.sum()/num

            return score

# %%
import torch
from torch import Tensor
import torch.nn.functional as F


def dice_coeff(input: Tensor, target: Tensor, reduce_batch_first: bool = False, epsilon=1e-6):
    # Average of Dice coefficient for all batches, or for a single mask
    assert input.size() == target.size()
    if input.dim() == 2 and reduce_batch_first:
        raise ValueError(
            f'Dice: asked to reduce batch but got tensor without batch dimension (shape {input.shape})')

    if input.dim() == 2 or reduce_batch_first:
        inter = torch.dot(input.reshape(-1), target.reshape(-1))
        sets_sum = torch.sum(input) + torch.sum(target)
        if sets_sum.item() == 0:
            sets_sum = 2 * inter

        return (2 * inter + epsilon) / (sets_sum + epsilon)
    else:
        # compute and average metric for each batch element
        dice = 0
        for i in range(input.shape[0]):
            dice += dice_coeff(input[i, ...], target[i, ...])
        return dice / input.shape[0]


def multiclass_dice_coeff(input: Tensor, target: Tensor, reduce_batch_first: bool = False, epsilon=1e-6):
    # Average of Dice coefficient for all classes
    assert input.size() == target.size()
    dice = 0
    for channel in range(input.shape[1]):
        dice += dice_coeff(input[:, channel, ...], target[:,
                           channel, ...], reduce_batch_first, epsilon)

    return dice / input.shape[1]


def dice_loss(input: Tensor, target: Tensor, multiclass: bool = False):
    # Dice loss (objective to minimize) between 0 and 1
    assert input.size() == target.size()
    fn = multiclass_dice_coeff if multiclass else dice_coeff
    return 1 - fn(input, target, reduce_batch_first=True)
