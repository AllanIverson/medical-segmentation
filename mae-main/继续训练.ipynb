# %%
# Copyright (c) Cyril Zakka.
# All rights reserved.

# This source code is licensed under the license found in the
# LICENSE file in the root directory of this source tree.
# --------------------------------------------------------
# Modified from:
# DeiT: https://github.com/facebookresearch/deit
# BEiT: https://github.com/microsoft/unilm/tree/master/beit
# MAE: https://github.com/facebookresearch/MAE
# --------------------------------------------------------
import argparse
import datetime
import json
from torch.utils.tensorboard import SummaryWriter
from PIL import Image
import numpy as np
import os
import time
from pathlib import Path

import torch
import torch.backends.cudnn as cudnn
import torchvision.transforms as transforms

import timm.optim.optim_factory as optim_factory

import util.misc as misc
from util.misc import NativeScalerWithGradNormCount as NativeScaler


import model_mae3d
from engine_pretrain3d import train_one_epoch




def get_args_parser():
    parser = argparse.ArgumentParser('MAE3D pre-training', add_help=False)
    parser.add_argument('--batch_size', default=1, type=int,
                        help='Batch size per GPU (effective batch size is batch_size * accum_iter * # gpus')
    parser.add_argument('--epochs', default=2000, type=int)
    parser.add_argument('--accum_iter', default=1, type=int,
                        help='Accumulate gradient iterations (for increasing the effective batch size under memory constraints)')

    # Model parameters
    parser.add_argument('--model', default='mae3d_vit_base_patch16', type=str, metavar='MODEL',
                        help='Name of model to train')
    parser.add_argument('--input_size', default=224, type=int,
                        help='images input size')
    parser.add_argument('--mask_ratio', default=0.75, type=float,
                        help='Masking ratio (percentage of removed patches).')
    parser.add_argument('--norm_pix_loss', action='store_true',
                        help='Use (per-patch) normalized pixels as targets for computing loss')
    parser.set_defaults(norm_pix_loss=False)

    # Optimizer parameters
    parser.add_argument('--weight_decay', type=float, default=0.05,
                        help='weight decay (default: 0.05)')
    parser.add_argument('--lr', type=float, default=1e-4, metavar='LR',
                        help='learning rate (absolute lr)')
    parser.add_argument('--blr', type=float, default=1e-4, metavar='LR',
                        help='base learning rate: absolute_lr = base_lr * total_batch_size / 256')
    parser.add_argument('--min_lr', type=float, default=0., metavar='LR',
                        help='lower lr bound for cyclic schedulers that hit 0')
    parser.add_argument('--warmup_epochs', type=int, default=0, metavar='N',
                        help='epochs to warmup LR')

    # Dataset parameters
    parser.add_argument('--data_path', default='/home/cyril/Datasets/MAE/', type=str,
                        help='dataset path')
    parser.add_argument('--num_segments', default=20, type=int)
    parser.add_argument('--frames_per_segment', default=8, type=int)
    parser.add_argument('--output_dir', default='./1000epoch_075_768_1e_4_dir',
                        help='path where to save, empty for no saving')
    parser.add_argument('--log_dir', default='./1000epoch_075_768_1e_4_dir',
                        help='path where to tensorboard log')
    parser.add_argument('--device', default='cuda:2',
                        help='device to use for training / testing')
    parser.add_argument('--seed', default=0, type=int)
    parser.add_argument('--resume', default='/data/zhanghao/skull_project/mae-main/1000epoch_075_768_1e_4_dir/checkpoint-999.pth',
                        help='resume from checkpoint')
    parser.add_argument('--start_epoch', default=1000, type=int, metavar='N',
                        help='start epoch')
    parser.add_argument('--num_workers', default=10, type=int)
    parser.add_argument('--pin_mem', action='store_true',
                        help='Pin CPU memory in DataLoader for more efficient (sometimes) transfer to GPU.')
    parser.add_argument('--no_pin_mem', action='store_false', dest='pin_mem')
    parser.set_defaults(pin_mem=True)

    # distributed training parameters
    parser.add_argument('--world_size', default=1, type=int,
                        help='number of distributed processes')
    parser.add_argument('--local_rank', default=-1, type=int)
    parser.add_argument('--dist_on_itp', action='store_true')
    parser.add_argument('--dist_url', default='env://',
                        help='url used to set up distributed training')

    return parser

# %%
from util.ccdataset3d import *
train_paths, valid_paths, test_paths = getPathList()
train_loader, valid_loader, test_loader = getDataloader(
    train_paths, valid_paths, test_paths, B1=1)
len(train_loader),len(valid_loader),len(test_loader)
#(1,1,160,224,224)
# Out:
# (274, 43, 42)

# %%
def main(args):
    # misc.init_distributed_mode(args)

    # print('job dir: {}'.format(os.path.dirname(os.path.realpath(__file__))))
    print("{}".format(args).replace(', ', ',\n'))

    device = torch.device(args.device)

    # fix the seed for reproducibility
    seed = args.seed + misc.get_rank()
    torch.manual_seed(seed)
    np.random.seed(seed)

    cudnn.benchmark = True

    if args.log_dir is not None:
        os.makedirs(args.log_dir, exist_ok=True)
        log_writer = SummaryWriter(log_dir=args.log_dir)

    # define the model
    model = model_mae3d.__dict__[args.model](
        num_frames=int(args.num_segments*args.frames_per_segment), norm_pix_loss=args.norm_pix_loss)
    model.to(device)

    model_without_ddp = model
    print("Model = %s" % str(model_without_ddp))

    eff_batch_size = args.batch_size * args.accum_iter * misc.get_world_size()
    
    # if args.lr is None:  # only base_lr is specified
    #     args.lr = args.blr * eff_batch_size / 256

    # print("base lr: %.2e" % (args.lr * 256 / eff_batch_size))
    print("actual lr: %.2e" % args.lr)

    print("accumulate grad iterations: %d" % args.accum_iter)
    print("effective batch size: %d" % eff_batch_size)

    # if args.distributed:
    #     model = torch.nn.parallel.DistributedDataParallel(model, device_ids=[args.gpu], find_unused_parameters=True)
    #     model_without_ddp = model.module
    
    # following timm: set wd as 0 for bias and norm layers
    param_groups = optim_factory.param_groups_weight_decay(
        model_without_ddp, args.weight_decay)
    optimizer = torch.optim.AdamW(param_groups, lr=args.lr, betas=(0.9, 0.95))
    print(optimizer)
    loss_scaler = NativeScaler()

    misc.load_model(args=args, model_without_ddp=model_without_ddp, optimizer=optimizer, loss_scaler=loss_scaler)

    print(f"Start training for {args.epochs} epochs")
    start_time = time.time()
    for epoch in range(args.start_epoch, args.epochs):
        # if args.distributed:
        #     train_loader.sampler.set_epoch(epoch)
        train_stats = train_one_epoch(
            model, train_loader,
            optimizer, device, epoch, loss_scaler,
            log_writer=None,
            args=args
        )
        if args.output_dir and (epoch % 20 == 0 or epoch + 1 == args.epochs):
            misc.save_model(
                args=args, model=model, model_without_ddp=model_without_ddp, optimizer=optimizer,
                loss_scaler=loss_scaler, epoch=epoch)

        log_stats = {**{f'train_{k}': v for k, v in train_stats.items()},
                        'epoch': epoch,}

        if args.output_dir and misc.is_main_process():
            if log_writer is not None:
                log_writer.flush()
            with open(os.path.join(args.output_dir, "log.txt"), mode="a", encoding="utf-8") as f:
                f.write(json.dumps(log_stats) + "\n")    

    total_time = time.time() - start_time
    total_time_str = str(datetime.timedelta(seconds=int(total_time)))
    print('Training time {}'.format(total_time_str))

# %%
args = get_args_parser()
args = args.parse_args(args=[])
if args.output_dir:
    Path(args.output_dir).mkdir(parents=True, exist_ok=True)
main(args)
# Out:
# Namespace(batch_size=1,
# epochs=2000,
# accum_iter=1,
# model='mae3d_vit_base_patch16',
# input_size=224,
# mask_ratio=0.75,
# norm_pix_loss=False,
# weight_decay=0.05,
# lr=0.0001,
# blr=0.0001,
# min_lr=0.0,
# warmup_epochs=0,
# data_path='/home/cyril/Datasets/MAE/',
# num_segments=20,
# frames_per_segment=8,
# output_dir='./1000epoch_075_768_1e_4_dir',
# log_dir='./1000epoch_075_768_1e_4_dir',
# device='cuda:2',
# seed=0,
# resume='/data/zhanghao/skull_project/mae-main/1000epoch_075_768_1e_4_dir/checkpoint-999.pth',
# start_epoch=1000,
# num_workers=10,
# pin_mem=True,
# world_size=1,
# local_rank=-1,
# dist_on_itp=False,
# dist_url='env://')
# Model = MAE3D(
#   (patch_embed): PatchEmbed3D(
#     (proj): Conv3d(1, 768, kernel_size=(8, 16, 16), stride=(8, 16, 16))
#     (norm): Identity()
#   )
#   (blocks): ModuleList(
#     (0): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (4): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (5): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (6): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (7): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (8): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (9): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (10): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (11): Block(
#       (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=768, out_features=2304, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=768, out_features=768, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=768, out_features=3072, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=3072, out_features=768, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (norm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   (decoder_embed): Linear(in_features=768, out_features=512, bias=True)
#   (decoder_blocks): ModuleList(
#     (0): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (1): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (2): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#     (3): Block(
#       (norm1): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (attn): Attention(
#         (qkv): Linear(in_features=512, out_features=1536, bias=True)
#         (attn_drop): Dropout(p=0.0, inplace=False)
#         (proj): Linear(in_features=512, out_features=512, bias=True)
#         (proj_drop): Dropout(p=0.0, inplace=False)
#       )
#       (ls1): Identity()
#       (drop_path1): Identity()
#       (norm2): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#       (mlp): Mlp(
#         (fc1): Linear(in_features=512, out_features=2048, bias=True)
#         (act): GELU()
#         (drop1): Dropout(p=0.0, inplace=False)
#         (fc2): Linear(in_features=2048, out_features=512, bias=True)
#         (drop2): Dropout(p=0.0, inplace=False)
#       )
#       (ls2): Identity()
#       (drop_path2): Identity()
#     )
#   )
#   (decoder_norm): LayerNorm((512,), eps=1e-06, elementwise_affine=True)
#   (decoder_pred): Linear(in_features=512, out_features=2048, bias=True)
# )
# actual lr: 1.00e-04
# accumulate grad iterations: 1
# effective batch size: 1
# AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.95)
#     eps: 1e-08
#     lr: 0.0001
#     weight_decay: 0.0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.95)
#     eps: 1e-08
#     lr: 0.0001
#     weight_decay: 0.05
# )
# Resume checkpoint /data/zhanghao/skull_project/mae-main/1000epoch_075_768_1e_4_dir/checkpoint-999.pth
# With optim & sched!
# Start training for 2000 epochs
# Averaged stats: lr: 0.000050  loss: 0.0031 (0.0027)
# Averaged stats: lr: 0.000050  loss: 0.0032 (0.0030)
# Averaged stats: lr: 0.000050  loss: 0.0030 (0.0029)
# Averaged stats: lr: 0.000050  loss: 0.0029 (0.0032)
# Averaged stats: lr: 0.000050  loss: 0.0032 (0.0030)
# Averaged stats: lr: 0.000050  loss: 0.0035 (0.0029)
# Averaged stats: lr: 0.000049  loss: 0.0028 (0.0031)
# Averaged stats: lr: 0.000049  loss: 0.0028 (0.0029)
# Averaged stats: lr: 0.000049  loss: 0.0032 (0.0029)
# Averaged stats: lr: 0.000049  loss: 0.0029 (0.0029)
# Averaged stats: lr: 0.000049  loss: 0.0032 (0.0029)
# Averaged stats: lr: 0.000049  loss: 0.0034 (0.0029)
# Averaged stats: lr: 0.000049  loss: 0.0031 (0.0029)
# Averaged stats: lr: 0.000049  loss: 0.0032 (0.0029)
# Averaged stats: lr: 0.000049  loss: 0.0031 (0.0028)
# Averaged stats: lr: 0.000049  loss: 0.0024 (0.0028)
# Averaged stats: lr: 0.000049  loss: 0.0029 (0.0029)
# Averaged stats: lr: 0.000049  loss: 0.0029 (0.0028)
# Averaged stats: lr: 0.000049  loss: 0.0033 (0.0028)
# Averaged stats: lr: 0.000048  loss: 0.0027 (0.0028)
# Averaged stats: lr: 0.000048  loss: 0.0031 (0.0029)
# Averaged stats: lr: 0.000048  loss: 0.0031 (0.0028)
# Averaged stats: lr: 0.000048  loss: 0.0030 (0.0028)
# Averaged stats: lr: 0.000048  loss: 0.0034 (0.0029)
# Averaged stats: lr: 0.000048  loss: 0.0027 (0.0028)
# Averaged stats: lr: 0.000048  loss: 0.0031 (0.0028)
# Averaged stats: lr: 0.000048  loss: 0.0031 (0.0028)
# Averaged stats: lr: 0.000048  loss: 0.0021 (0.0028)
# Averaged stats: lr: 0.000048  loss: 0.0026 (0.0028)
# Averaged stats: lr: 0.000048  loss: 0.0021 (0.0028)
# Averaged stats: lr: 0.000048  loss: 0.0031 (0.0028)
# Averaged stats: lr: 0.000047  loss: 0.0028 (0.0028)
# Averaged stats: lr: 0.000047  loss: 0.0031 (0.0028)
# Averaged stats: lr: 0.000047  loss: 0.0031 (0.0028)
# Averaged stats: lr: 0.000047  loss: 0.0030 (0.0028)
# Averaged stats: lr: 0.000047  loss: 0.0026 (0.0028)
# Averaged stats: lr: 0.000047  loss: 0.0030 (0.0028)
# Averaged stats: lr: 0.000047  loss: 0.0027 (0.0028)
# Averaged stats: lr: 0.000047  loss: 0.0032 (0.0027)
# Averaged stats: lr: 0.000047  loss: 0.0029 (0.0027)
# Averaged stats: lr: 0.000047  loss: 0.0026 (0.0027)
# Averaged stats: lr: 0.000047  loss: 0.0029 (0.0028)
# Averaged stats: lr: 0.000047  loss: 0.0028 (0.0027)
# Averaged stats: lr: 0.000047  loss: 0.0027 (0.0027)
# Averaged stats: lr: 0.000046  loss: 0.0026 (0.0028)
# Averaged stats: lr: 0.000046  loss: 0.0033 (0.0028)
# Averaged stats: lr: 0.000046  loss: 0.0030 (0.0027)
# Averaged stats: lr: 0.000046  loss: 0.0021 (0.0027)
# Averaged stats: lr: 0.000046  loss: 0.0030 (0.0027)
# Averaged stats: lr: 0.000046  loss: 0.0028 (0.0027)
# Averaged stats: lr: 0.000046  loss: 0.0031 (0.0027)
# Averaged stats: lr: 0.000046  loss: 0.0025 (0.0027)
# Averaged stats: lr: 0.000046  loss: 0.0030 (0.0028)
# Averaged stats: lr: 0.000046  loss: 0.0027 (0.0028)
# Averaged stats: lr: 0.000046  loss: 0.0029 (0.0028)
# Averaged stats: lr: 0.000046  loss: 0.0027 (0.0027)
# Averaged stats: lr: 0.000046  loss: 0.0031 (0.0027)
# Averaged stats: lr: 0.000045  loss: 0.0029 (0.0027)
# Averaged stats: lr: 0.000045  loss: 0.0032 (0.0027)
# Averaged stats: lr: 0.000045  loss: 0.0027 (0.0027)
# Averaged stats: lr: 0.000045  loss: 0.0033 (0.0027)
# Averaged stats: lr: 0.000045  loss: 0.0030 (0.0027)
# Averaged stats: lr: 0.000045  loss: 0.0029 (0.0027)
# Averaged stats: lr: 0.000045  loss: 0.0029 (0.0027)
# Averaged stats: lr: 0.000045  loss: 0.0027 (0.0027)
# Averaged stats: lr: 0.000045  loss: 0.0026 (0.0027)
# Averaged stats: lr: 0.000045  loss: 0.0025 (0.0027)
# Averaged stats: lr: 0.000045  loss: 0.0029 (0.0027)
# Averaged stats: lr: 0.000045  loss: 0.0031 (0.0027)
# Averaged stats: lr: 0.000045  loss: 0.0025 (0.0027)
# Averaged stats: lr: 0.000044  loss: 0.0022 (0.0026)
# Averaged stats: lr: 0.000044  loss: 0.0022 (0.0027)
# Averaged stats: lr: 0.000044  loss: 0.0027 (0.0026)
# Averaged stats: lr: 0.000044  loss: 0.0019 (0.0027)
# Averaged stats: lr: 0.000044  loss: 0.0019 (0.0026)
# Averaged stats: lr: 0.000044  loss: 0.0027 (0.0026)
# Averaged stats: lr: 0.000044  loss: 0.0029 (0.0026)
# Averaged stats: lr: 0.000044  loss: 0.0032 (0.0026)
# Averaged stats: lr: 0.000044  loss: 0.0028 (0.0026)
# Averaged stats: lr: 0.000044  loss: 0.0024 (0.0027)
# Averaged stats: lr: 0.000044  loss: 0.0028 (0.0026)
# Averaged stats: lr: 0.000044  loss: 0.0025 (0.0026)
# Averaged stats: lr: 0.000043  loss: 0.0026 (0.0027)
# Averaged stats: lr: 0.000043  loss: 0.0031 (0.0026)
# Averaged stats: lr: 0.000043  loss: 0.0030 (0.0026)
# Averaged stats: lr: 0.000043  loss: 0.0026 (0.0026)
# Averaged stats: lr: 0.000043  loss: 0.0029 (0.0026)
# Averaged stats: lr: 0.000043  loss: 0.0025 (0.0026)
# Averaged stats: lr: 0.000043  loss: 0.0030 (0.0027)
# Averaged stats: lr: 0.000043  loss: 0.0030 (0.0026)
# Averaged stats: lr: 0.000043  loss: 0.0027 (0.0026)
# Averaged stats: lr: 0.000043  loss: 0.0026 (0.0026)
# Averaged stats: lr: 0.000043  loss: 0.0029 (0.0026)
# Averaged stats: lr: 0.000043  loss: 0.0031 (0.0026)
# Averaged stats: lr: 0.000043  loss: 0.0021 (0.0026)
# Averaged stats: lr: 0.000042  loss: 0.0025 (0.0026)
# Averaged stats: lr: 0.000042  loss: 0.0028 (0.0026)
# Averaged stats: lr: 0.000042  loss: 0.0028 (0.0026)
# Averaged stats: lr: 0.000042  loss: 0.0025 (0.0026)
# Averaged stats: lr: 0.000042  loss: 0.0025 (0.0026)
# Averaged stats: lr: 0.000042  loss: 0.0025 (0.0026)
# Averaged stats: lr: 0.000042  loss: 0.0024 (0.0026)
# Averaged stats: lr: 0.000042  loss: 0.0026 (0.0026)
# Averaged stats: lr: 0.000042  loss: 0.0029 (0.0026)
# Averaged stats: lr: 0.000042  loss: 0.0029 (0.0027)
# Averaged stats: lr: 0.000042  loss: 0.0031 (0.0026)
# Averaged stats: lr: 0.000042  loss: 0.0030 (0.0026)
# Averaged stats: lr: 0.000042  loss: 0.0024 (0.0026)
# Averaged stats: lr: 0.000041  loss: 0.0020 (0.0026)
# Averaged stats: lr: 0.000041  loss: 0.0022 (0.0026)
# Averaged stats: lr: 0.000041  loss: 0.0029 (0.0026)
# Averaged stats: lr: 0.000041  loss: 0.0023 (0.0026)
# Averaged stats: lr: 0.000041  loss: 0.0027 (0.0026)
# Averaged stats: lr: 0.000041  loss: 0.0029 (0.0026)
# Averaged stats: lr: 0.000041  loss: 0.0029 (0.0025)
# Averaged stats: lr: 0.000041  loss: 0.0027 (0.0026)
# Averaged stats: lr: 0.000041  loss: 0.0024 (0.0025)
# Averaged stats: lr: 0.000041  loss: 0.0027 (0.0025)
# Averaged stats: lr: 0.000041  loss: 0.0030 (0.0025)
# Averaged stats: lr: 0.000041  loss: 0.0025 (0.0025)
# Averaged stats: lr: 0.000041  loss: 0.0027 (0.0026)
# Averaged stats: lr: 0.000040  loss: 0.0018 (0.0025)
# Averaged stats: lr: 0.000040  loss: 0.0024 (0.0025)
# Averaged stats: lr: 0.000040  loss: 0.0031 (0.0025)
# Averaged stats: lr: 0.000040  loss: 0.0019 (0.0025)
# Averaged stats: lr: 0.000040  loss: 0.0024 (0.0025)
# Averaged stats: lr: 0.000040  loss: 0.0029 (0.0025)
# Averaged stats: lr: 0.000040  loss: 0.0023 (0.0025)
# Averaged stats: lr: 0.000040  loss: 0.0029 (0.0025)
# Averaged stats: lr: 0.000040  loss: 0.0026 (0.0025)
# Averaged stats: lr: 0.000040  loss: 0.0026 (0.0025)
# Averaged stats: lr: 0.000040  loss: 0.0030 (0.0025)
# Averaged stats: lr: 0.000040  loss: 0.0024 (0.0025)
# Averaged stats: lr: 0.000040  loss: 0.0025 (0.0025)
# Averaged stats: lr: 0.000039  loss: 0.0027 (0.0025)
# Averaged stats: lr: 0.000039  loss: 0.0026 (0.0025)
# Averaged stats: lr: 0.000039  loss: 0.0031 (0.0025)
# Averaged stats: lr: 0.000039  loss: 0.0022 (0.0025)
# Averaged stats: lr: 0.000039  loss: 0.0029 (0.0025)
# Averaged stats: lr: 0.000039  loss: 0.0022 (0.0025)
# Averaged stats: lr: 0.000039  loss: 0.0023 (0.0025)
# Averaged stats: lr: 0.000039  loss: 0.0027 (0.0025)
# Averaged stats: lr: 0.000039  loss: 0.0027 (0.0025)
# Averaged stats: lr: 0.000039  loss: 0.0024 (0.0025)
# Averaged stats: lr: 0.000039  loss: 0.0020 (0.0025)
# Averaged stats: lr: 0.000039  loss: 0.0029 (0.0025)
# Averaged stats: lr: 0.000039  loss: 0.0028 (0.0025)
# Averaged stats: lr: 0.000038  loss: 0.0027 (0.0025)
# Averaged stats: lr: 0.000038  loss: 0.0025 (0.0025)
# Averaged stats: lr: 0.000038  loss: 0.0027 (0.0025)
# Averaged stats: lr: 0.000038  loss: 0.0025 (0.0025)
# Averaged stats: lr: 0.000038  loss: 0.0029 (0.0025)
# Averaged stats: lr: 0.000038  loss: 0.0025 (0.0025)
# Averaged stats: lr: 0.000038  loss: 0.0025 (0.0025)
# Averaged stats: lr: 0.000038  loss: 0.0027 (0.0025)
# Averaged stats: lr: 0.000038  loss: 0.0022 (0.0024)
# Averaged stats: lr: 0.000038  loss: 0.0027 (0.0025)
# Averaged stats: lr: 0.000038  loss: 0.0030 (0.0025)
# Averaged stats: lr: 0.000038  loss: 0.0024 (0.0025)
# Averaged stats: lr: 0.000038  loss: 0.0027 (0.0025)
# Averaged stats: lr: 0.000037  loss: 0.0027 (0.0024)
# Averaged stats: lr: 0.000037  loss: 0.0026 (0.0025)
# Averaged stats: lr: 0.000037  loss: 0.0028 (0.0024)
# Averaged stats: lr: 0.000037  loss: 0.0024 (0.0024)
# Averaged stats: lr: 0.000037  loss: 0.0029 (0.0025)
# Averaged stats: lr: 0.000037  loss: 0.0024 (0.0025)
# Averaged stats: lr: 0.000037  loss: 0.0026 (0.0024)
# Averaged stats: lr: 0.000037  loss: 0.0026 (0.0024)
# Averaged stats: lr: 0.000037  loss: 0.0028 (0.0024)
# Averaged stats: lr: 0.000037  loss: 0.0023 (0.0024)
# Averaged stats: lr: 0.000037  loss: 0.0028 (0.0024)
# Averaged stats: lr: 0.000037  loss: 0.0026 (0.0024)
# Averaged stats: lr: 0.000037  loss: 0.0027 (0.0024)
# Averaged stats: lr: 0.000037  loss: 0.0028 (0.0024)
# Averaged stats: lr: 0.000036  loss: 0.0027 (0.0024)
# Averaged stats: lr: 0.000036  loss: 0.0030 (0.0024)
# Averaged stats: lr: 0.000036  loss: 0.0024 (0.0024)
# Averaged stats: lr: 0.000036  loss: 0.0027 (0.0024)
# Averaged stats: lr: 0.000036  loss: 0.0023 (0.0024)
# Averaged stats: lr: 0.000036  loss: 0.0028 (0.0024)
# Averaged stats: lr: 0.000036  loss: 0.0029 (0.0024)
# Averaged stats: lr: 0.000036  loss: 0.0028 (0.0024)
# Averaged stats: lr: 0.000036  loss: 0.0023 (0.0024)
# Averaged stats: lr: 0.000036  loss: 0.0027 (0.0024)
# Averaged stats: lr: 0.000036  loss: 0.0024 (0.0024)
# Averaged stats: lr: 0.000036  loss: 0.0021 (0.0024)
# Averaged stats: lr: 0.000036  loss: 0.0025 (0.0024)
# Averaged stats: lr: 0.000035  loss: 0.0025 (0.0024)
# Averaged stats: lr: 0.000035  loss: 0.0021 (0.0024)
# Averaged stats: lr: 0.000035  loss: 0.0026 (0.0024)
# Averaged stats: lr: 0.000035  loss: 0.0028 (0.0024)
# Averaged stats: lr: 0.000035  loss: 0.0026 (0.0024)
# Averaged stats: lr: 0.000035  loss: 0.0021 (0.0024)
# Averaged stats: lr: 0.000035  loss: 0.0021 (0.0024)
# Averaged stats: lr: 0.000035  loss: 0.0028 (0.0024)
# Averaged stats: lr: 0.000035  loss: 0.0025 (0.0024)
# Averaged stats: lr: 0.000035  loss: 0.0028 (0.0024)
# Averaged stats: lr: 0.000035  loss: 0.0022 (0.0024)
# Averaged stats: lr: 0.000035  loss: 0.0022 (0.0024)
# Averaged stats: lr: 0.000035  loss: 0.0023 (0.0024)
# Averaged stats: lr: 0.000034  loss: 0.0027 (0.0024)
# Averaged stats: lr: 0.000034  loss: 0.0023 (0.0024)
# Averaged stats: lr: 0.000034  loss: 0.0023 (0.0024)
# Averaged stats: lr: 0.000034  loss: 0.0024 (0.0024)
# Averaged stats: lr: 0.000034  loss: 0.0023 (0.0024)
# Averaged stats: lr: 0.000034  loss: 0.0027 (0.0023)
# Averaged stats: lr: 0.000034  loss: 0.0023 (0.0024)
# Averaged stats: lr: 0.000034  loss: 0.0026 (0.0024)
# Averaged stats: lr: 0.000034  loss: 0.0026 (0.0024)
# Averaged stats: lr: 0.000034  loss: 0.0021 (0.0023)
# Averaged stats: lr: 0.000034  loss: 0.0024 (0.0023)
# Averaged stats: lr: 0.000034  loss: 0.0023 (0.0024)
# Averaged stats: lr: 0.000034  loss: 0.0028 (0.0024)
# Averaged stats: lr: 0.000034  loss: 0.0025 (0.0023)
# Averaged stats: lr: 0.000033  loss: 0.0028 (0.0024)
# Averaged stats: lr: 0.000033  loss: 0.0020 (0.0024)
# Averaged stats: lr: 0.000033  loss: 0.0025 (0.0023)
# Averaged stats: lr: 0.000033  loss: 0.0027 (0.0023)
# Averaged stats: lr: 0.000033  loss: 0.0019 (0.0023)
# Averaged stats: lr: 0.000033  loss: 0.0025 (0.0023)
# Averaged stats: lr: 0.000033  loss: 0.0027 (0.0023)
# Averaged stats: lr: 0.000033  loss: 0.0027 (0.0023)
# Averaged stats: lr: 0.000033  loss: 0.0024 (0.0024)
# Averaged stats: lr: 0.000033  loss: 0.0025 (0.0023)
# Averaged stats: lr: 0.000033  loss: 0.0025 (0.0023)
# Averaged stats: lr: 0.000033  loss: 0.0025 (0.0023)
# Averaged stats: lr: 0.000033  loss: 0.0025 (0.0023)
# Averaged stats: lr: 0.000032  loss: 0.0026 (0.0023)
# Averaged stats: lr: 0.000032  loss: 0.0029 (0.0023)
# Averaged stats: lr: 0.000032  loss: 0.0022 (0.0023)
# Averaged stats: lr: 0.000032  loss: 0.0024 (0.0023)
# Averaged stats: lr: 0.000032  loss: 0.0027 (0.0023)
# Averaged stats: lr: 0.000032  loss: 0.0027 (0.0023)
# Averaged stats: lr: 0.000032  loss: 0.0020 (0.0023)
# Averaged stats: lr: 0.000032  loss: 0.0022 (0.0023)
# Averaged stats: lr: 0.000032  loss: 0.0018 (0.0023)
# Averaged stats: lr: 0.000032  loss: 0.0027 (0.0023)
# Averaged stats: lr: 0.000032  loss: 0.0021 (0.0023)
# Averaged stats: lr: 0.000032  loss: 0.0018 (0.0023)
# Averaged stats: lr: 0.000032  loss: 0.0023 (0.0023)
# Averaged stats: lr: 0.000032  loss: 0.0023 (0.0023)
# Averaged stats: lr: 0.000031  loss: 0.0022 (0.0023)
# Averaged stats: lr: 0.000031  loss: 0.0026 (0.0023)
# Averaged stats: lr: 0.000031  loss: 0.0023 (0.0023)
# Averaged stats: lr: 0.000031  loss: 0.0027 (0.0023)
# Averaged stats: lr: 0.000031  loss: 0.0023 (0.0023)
# Averaged stats: lr: 0.000031  loss: 0.0022 (0.0023)
# Averaged stats: lr: 0.000031  loss: 0.0025 (0.0023)
# Averaged stats: lr: 0.000031  loss: 0.0026 (0.0023)
# Averaged stats: lr: 0.000031  loss: 0.0024 (0.0023)
# Averaged stats: lr: 0.000031  loss: 0.0021 (0.0023)
# Averaged stats: lr: 0.000031  loss: 0.0023 (0.0023)
# Averaged stats: lr: 0.000031  loss: 0.0025 (0.0023)
# Averaged stats: lr: 0.000031  loss: 0.0022 (0.0023)
# Averaged stats: lr: 0.000031  loss: 0.0026 (0.0023)
# Averaged stats: lr: 0.000030  loss: 0.0026 (0.0023)
# Averaged stats: lr: 0.000030  loss: 0.0024 (0.0023)
# Averaged stats: lr: 0.000030  loss: 0.0025 (0.0023)
# Averaged stats: lr: 0.000030  loss: 0.0019 (0.0023)
# Averaged stats: lr: 0.000030  loss: 0.0020 (0.0023)
# Averaged stats: lr: 0.000030  loss: 0.0025 (0.0023)
# Averaged stats: lr: 0.000030  loss: 0.0020 (0.0023)
# Averaged stats: lr: 0.000030  loss: 0.0018 (0.0023)
# Averaged stats: lr: 0.000030  loss: 0.0022 (0.0023)
# Averaged stats: lr: 0.000030  loss: 0.0020 (0.0023)
# Averaged stats: lr: 0.000030  loss: 0.0025 (0.0023)
# Averaged stats: lr: 0.000030  loss: 0.0026 (0.0023)
# Averaged stats: lr: 0.000030  loss: 0.0026 (0.0023)
# Averaged stats: lr: 0.000029  loss: 0.0028 (0.0023)
# Averaged stats: lr: 0.000029  loss: 0.0023 (0.0023)
# Averaged stats: lr: 0.000029  loss: 0.0022 (0.0023)
# Averaged stats: lr: 0.000029  loss: 0.0021 (0.0023)
# Averaged stats: lr: 0.000029  loss: 0.0022 (0.0022)
# Averaged stats: lr: 0.000029  loss: 0.0026 (0.0023)
# Averaged stats: lr: 0.000029  loss: 0.0021 (0.0023)
# Averaged stats: lr: 0.000029  loss: 0.0023 (0.0023)
# Averaged stats: lr: 0.000029  loss: 0.0018 (0.0023)
# Averaged stats: lr: 0.000029  loss: 0.0024 (0.0023)
# Averaged stats: lr: 0.000029  loss: 0.0020 (0.0022)
# Averaged stats: lr: 0.000029  loss: 0.0017 (0.0023)
# Averaged stats: lr: 0.000029  loss: 0.0018 (0.0022)
# Averaged stats: lr: 0.000029  loss: 0.0021 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0023 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0026 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0022 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0015 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0025 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0025 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0025 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0020 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0021 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0021 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0026 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0022 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0025 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0022 (0.0022)
# Averaged stats: lr: 0.000028  loss: 0.0021 (0.0022)
# Averaged stats: lr: 0.000027  loss: 0.0022 (0.0022)
# Averaged stats: lr: 0.000027  loss: 0.0022 (0.0022)
# Averaged stats: lr: 0.000027  loss: 0.0025 (0.0022)
# Averaged stats: lr: 0.000027  loss: 0.0026 (0.0022)
# Averaged stats: lr: 0.000027  loss: 0.0021 (0.0022)
# Averaged stats: lr: 0.000027  loss: 0.0019 (0.0022)
# Averaged stats: lr: 0.000027  loss: 0.0023 (0.0022)
# Averaged stats: lr: 0.000027  loss: 0.0023 (0.0022)
# Averaged stats: lr: 0.000027  loss: 0.0020 (0.0022)
# Averaged stats: lr: 0.000027  loss: 0.0024 (0.0022)
# Averaged stats: lr: 0.000027  loss: 0.0022 (0.0022)
# Averaged stats: lr: 0.000027  loss: 0.0026 (0.0022)
# Averaged stats: lr: 0.000027  loss: 0.0025 (0.0022)
# Averaged stats: lr: 0.000027  loss: 0.0021 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0025 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0021 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0026 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0024 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0022 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0018 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0021 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0020 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0021 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0020 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0023 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0024 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0018 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0017 (0.0022)
# Averaged stats: lr: 0.000026  loss: 0.0022 (0.0022)
# Averaged stats: lr: 0.000025  loss: 0.0025 (0.0022)
# Averaged stats: lr: 0.000025  loss: 0.0024 (0.0022)
# Averaged stats: lr: 0.000025  loss: 0.0021 (0.0022)
# Averaged stats: lr: 0.000025  loss: 0.0022 (0.0022)
# Averaged stats: lr: 0.000025  loss: 0.0023 (0.0022)
# Averaged stats: lr: 0.000025  loss: 0.0024 (0.0022)
# Averaged stats: lr: 0.000025  loss: 0.0020 (0.0022)
# Averaged stats: lr: 0.000025  loss: 0.0022 (0.0022)
# Averaged stats: lr: 0.000025  loss: 0.0020 (0.0022)
# Averaged stats: lr: 0.000025  loss: 0.0024 (0.0022)
# Averaged stats: lr: 0.000025  loss: 0.0019 (0.0022)
# Averaged stats: lr: 0.000025  loss: 0.0018 (0.0022)
# Averaged stats: lr: 0.000025  loss: 0.0021 (0.0022)
# Averaged stats: lr: 0.000025  loss: 0.0025 (0.0022)
# Averaged stats: lr: 0.000024  loss: 0.0021 (0.0022)
# Averaged stats: lr: 0.000024  loss: 0.0022 (0.0022)
# Averaged stats: lr: 0.000024  loss: 0.0025 (0.0022)
# Averaged stats: lr: 0.000024  loss: 0.0024 (0.0022)
# Averaged stats: lr: 0.000024  loss: 0.0019 (0.0022)
# Averaged stats: lr: 0.000024  loss: 0.0022 (0.0022)
# Averaged stats: lr: 0.000024  loss: 0.0021 (0.0022)
# Averaged stats: lr: 0.000024  loss: 0.0017 (0.0022)
# Averaged stats: lr: 0.000024  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000024  loss: 0.0020 (0.0022)
# Averaged stats: lr: 0.000024  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000024  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000024  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000024  loss: 0.0019 (0.0021)
# Averaged stats: lr: 0.000024  loss: 0.0025 (0.0022)
# Averaged stats: lr: 0.000023  loss: 0.0026 (0.0021)
# Averaged stats: lr: 0.000023  loss: 0.0026 (0.0021)
# Averaged stats: lr: 0.000023  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000023  loss: 0.0022 (0.0021)
# Averaged stats: lr: 0.000023  loss: 0.0023 (0.0021)
# Averaged stats: lr: 0.000023  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000023  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000023  loss: 0.0018 (0.0021)
# Averaged stats: lr: 0.000023  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000023  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000023  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000023  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000023  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000023  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000023  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0023 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0026 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0017 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0019 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0019 (0.0021)
# Averaged stats: lr: 0.000022  loss: 0.0023 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0026 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0017 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0016 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0022 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000021  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0022 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0016 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0018 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0017 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0015 (0.0021)
# Averaged stats: lr: 0.000020  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0023 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0019 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0023 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0023 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0023 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0019 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0016 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0017 (0.0021)
# Averaged stats: lr: 0.000019  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0018 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0023 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0016 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0025 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0019 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0022 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0022 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0023 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0021 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0014 (0.0021)
# Averaged stats: lr: 0.000018  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000017  loss: 0.0020 (0.0021)
# Averaged stats: lr: 0.000017  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000017  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000017  loss: 0.0017 (0.0020)
# Averaged stats: lr: 0.000017  loss: 0.0017 (0.0020)
# Averaged stats: lr: 0.000017  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000017  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000017  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000017  loss: 0.0016 (0.0020)
# Averaged stats: lr: 0.000017  loss: 0.0015 (0.0020)
# Averaged stats: lr: 0.000017  loss: 0.0024 (0.0021)
# Averaged stats: lr: 0.000017  loss: 0.0018 (0.0020)
# Averaged stats: lr: 0.000017  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000017  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000017  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000017  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000017  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0019 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0021 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0021 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0018 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0019 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0021 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0016 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0022 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000016  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0019 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0025 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0019 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0016 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0018 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0026 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0017 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0021 (0.0020)
# Averaged stats: lr: 0.000015  loss: 0.0022 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0021 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0016 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0014 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0019 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0016 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0017 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0019 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0022 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0015 (0.0020)
# Averaged stats: lr: 0.000014  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0022 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0022 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0019 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0018 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0018 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000013  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0022 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0022 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0013 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0019 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0015 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0021 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0017 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0017 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0021 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0021 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0017 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0016 (0.0020)
# Averaged stats: lr: 0.000012  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0018 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0021 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0018 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0021 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0019 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0021 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0017 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0018 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0022 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0015 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000011  loss: 0.0021 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0017 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0021 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0019 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0016 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0019 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0022 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0022 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0021 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0022 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0015 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0016 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0020 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0023 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000010  loss: 0.0019 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0019 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0022 (0.0020)
# Averaged stats: lr: 0.000010  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000010  loss: 0.0016 (0.0020)
# Averaged stats: lr: 0.000009  loss: 0.0024 (0.0020)
# Averaged stats: lr: 0.000009  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0023 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0023 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0014 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0023 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000009  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000008  loss: 0.0018 (0.0019)
# ...
# Averaged stats: lr: 0.000005  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000005  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0023 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0023 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0024 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000004  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0014 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0014 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0023 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0014 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0023 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000003  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0014 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0023 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0014 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0023 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0014 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000002  loss: 0.0023 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0024 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0014 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000001  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0023 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0023 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0013 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0020 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0014 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0014 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0016 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0015 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0022 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0023 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0017 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0019 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0018 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0021 (0.0019)
# Averaged stats: lr: 0.000000  loss: 0.0015 (0.0019)
# Training time 20:39:23
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
