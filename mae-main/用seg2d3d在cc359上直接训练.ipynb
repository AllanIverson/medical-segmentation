# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.
# All rights reserved.

# This source code is licensed under the license found in the
# LICENSE file in the root directory of this source tree.
# --------------------------------------------------------
# References:
# DeiT: https://github.com/facebookresearch/deit
# BEiT: https://github.com/microsoft/unilm/tree/master/beit
# --------------------------------------------------------

import timm.optim.optim_factory as optim_factory
import argparse
import datetime
import json
import numpy as np
import os
import time
from pathlib import Path

import torch
import torch.backends.cudnn as cudnn
from torch.utils.tensorboard import SummaryWriter

import timm

# assert timm.__version__ == "0.3.2" # version check
from timm.models.layers import trunc_normal_
from timm.data.mixup import Mixup
from timm.loss import LabelSmoothingCrossEntropy, SoftTargetCrossEntropy

import util.lr_decay as lrd
import util.misc as misc
from util.datasets import build_dataset
from util.pos_embed import interpolate_pos_embed
from util.misc import NativeScalerWithGradNormCount as NativeScaler

import models_vit

from engine_finetune import train_one_epoch, evaluate


def get_args_parser():
    parser = argparse.ArgumentParser('MAE fine-tuning for image segmentation', add_help=False)
    parser.add_argument('--batch_size', default=64, type=int,
                        help='Batch size per GPU (effective batch size is batch_size * accum_iter * # gpus')
    parser.add_argument('--epochs', default=300, type=int)
    parser.add_argument('--accum_iter', default=1, type=int,
                        help='Accumulate gradient iterations (for increasing the effective batch size under memory constraints)')

    # Model parameters
    parser.add_argument('--encoder_model', default='mae_vit_block9_base_patch16', type=str, metavar='MODEL',
                        help='Name of encoder pretrained')

    parser.add_argument('--model',default='mae_vit3d_medical_768_512_windowsize4',type=str,
                        help='Name of model to train')

    parser.add_argument('--input_size', default=224, type=int,
                        help='images input size')

    parser.add_argument('--drop_path', type=float, default=0.1, metavar='PCT',
                        help='Drop path rate (default: 0.1)')
    


    # Optimizer parameters
    parser.add_argument('--clip_grad', type=float, default=None, metavar='NORM',
                        help='Clip gradient norm (default: None, no clipping)')
    parser.add_argument('--weight_decay', type=float, default=0.05,
                        help='weight decay (default: 0.05)')

    parser.add_argument('--lr', type=float, default=1e-4, metavar='LR',
                        help='learning rate (absolute lr)')
    parser.add_argument('--blr', type=float, default=1e-4, metavar='LR',
                        help='base learning rate: absolute_lr = base_lr * total_batch_size / 256')
    parser.add_argument('--layer_decay', type=float, default=0.5,
                        help='layer-wise lr decay from ELECTRA/BEiT')

    parser.add_argument('--min_lr', type=float, default=1e-6, metavar='LR',
                        help='lower lr bound for cyclic schedulers that hit 0')

    parser.add_argument('--warmup_epochs', type=int, default=5, metavar='N',
                        help='epochs to warmup LR')

    # Augmentation parameters
    parser.add_argument('--color_jitter', type=float, default=None, metavar='PCT',
                        help='Color jitter factor (enabled only when not using Auto/RandAug)')
    parser.add_argument('--aa', type=str, default='rand-m9-mstd0.5-inc1', metavar='NAME',
                        help='Use AutoAugment policy. "v0" or "original". " + "(default: rand-m9-mstd0.5-inc1)'),
    parser.add_argument('--smoothing', type=float, default=0.1,
                        help='Label smoothing (default: 0.1)')

    # * Random Erase params
    parser.add_argument('--reprob', type=float, default=0.25, metavar='PCT',
                        help='Random erase prob (default: 0.25)')
    parser.add_argument('--remode', type=str, default='pixel',
                        help='Random erase mode (default: "pixel")')
    parser.add_argument('--recount', type=int, default=1,
                        help='Random erase count (default: 1)')
    parser.add_argument('--resplit', action='store_true', default=False,
                        help='Do not random erase first (clean) augmentation split')

    # * Mixup params
    parser.add_argument('--mixup', type=float, default=0,
                        help='mixup alpha, mixup enabled if > 0.')
    parser.add_argument('--cutmix', type=float, default=0,
                        help='cutmix alpha, cutmix enabled if > 0.')
    parser.add_argument('--cutmix_minmax', type=float, nargs='+', default=None,
                        help='cutmix min/max ratio, overrides alpha and enables cutmix if set (default: None)')
    parser.add_argument('--mixup_prob', type=float, default=1.0,
                        help='Probability of performing mixup or cutmix when either/both is enabled')
    parser.add_argument('--mixup_switch_prob', type=float, default=0.5,
                        help='Probability of switching to cutmix when both mixup and cutmix enabled')
    parser.add_argument('--mixup_mode', type=str, default='batch',
                        help='How to apply mixup/cutmix params. Per "batch", "pair", or "elem"')

    # * Finetuning params
    parser.add_argument('--finetune', default='./mae-main/oasis_cc359_half_pretrain_out_norm/checkpoint-799.pth',
                        help='finetune from checkpoint')
    parser.add_argument('--global_pool', action='store_true')
    parser.set_defaults(global_pool=True)
    parser.add_argument('--cls_token', action='store_false', dest='global_pool',
                        help='Use class token instead of global pool for classification')

    # Dataset parameters
    parser.add_argument('--data_path', default='/datasets01/imagenet_full_size/061417/', type=str,
                        help='dataset path')
    parser.add_argument('--nb_classes', default=1000, type=int,
                        help='number of the classification types')

    parser.add_argument('--output_dir', default='/data/zhanghao/skull_project/mae-main/base_line/3d_cc359_010data_half_norm_800_extra_freeze5/',
                        help='path where to save, empty for no saving')
    parser.add_argument('--log_dir', default='/data/zhanghao/skull_project/mae-main/base_line/3d_cc359_010data_half_norm_800_extra_freeze5',
                        help='path where to tensorboard log')
    parser.add_argument('--device', default='cuda:0',
                        help='device to use for training / testing')
    parser.add_argument('--seed', default=0, type=int)
    parser.add_argument('--resume', default='',
                        help='resume from checkpoint')

    parser.add_argument('--start_epoch', default=0, type=int, metavar='N',
                        help='start epoch')
    parser.add_argument('--eval', action='store_true',
                        help='Perform evaluation only')
    parser.add_argument('--dist_eval', action='store_true', default=False,
                        help='Enabling distributed evaluation (recommended during training for faster monitor')
    parser.add_argument('--num_workers', default=10, type=int)
    parser.add_argument('--pin_mem', action='store_true',
                        help='Pin CPU memory in DataLoader for more efficient (sometimes) transfer to GPU.')
    parser.add_argument('--no_pin_mem', action='store_false', dest='pin_mem')
    parser.set_defaults(pin_mem=True)

    # distributed training parameters
    parser.add_argument('--world_size', default=1, type=int,
                        help='number of distributed processes')
    parser.add_argument('--local_rank', default=-1, type=int)
    parser.add_argument('--dist_on_itp', action='store_true')
    parser.add_argument('--dist_url', default='env://',
                        help='url used to set up distributed training')

    return parser

# %%
from util.ccdataset3d import *
train_path, valid_path, test_path = getPathList()

train_loader = getDataloader010(
    train_path,valid_paths=None,test_paths=None, B1=1)
_,valid_loader,test_loader = getDataloader(
    train_path, valid_path, test_path,B1=1
)
len(train_loader),len(valid_loader),len(test_loader)
#(1,1,160,224,224)
# Out:
# (27, 43, 42)

# %%
from ast import arg
import my_seg_vit
import util.lr_sched as lr_sched
import math
import sys
from my_metric import dice_coef_metric,jaccard_coef_metric
import seg3d_2dencoder 
import maeseg2d3d 
def main(args):
    device = torch.device(args.device)

    os.makedirs(args.log_dir, exist_ok=True)
    log_writer = SummaryWriter(log_dir=args.log_dir)

    # fix the seed for reproducibility
    seed = args.seed + misc.get_rank()
    torch.manual_seed(seed)
    np.random.seed(seed) 

    cudnn.benchmark = True  
    
    #load encoder
    encoder = seg3d_2dencoder.__dict__[args.encoder_model](lossforpatch = False)

    #load dict
    checkpoiont = torch.load(args.finetune,map_location='cpu')
    print("Load pre-trained checkpoint from: %s" % args.finetune)
    checkpoint_model = checkpoiont['model']

    state_dict = encoder.state_dict()
    for k in ['head.weight', 'head.bias']:
        if k in checkpoint_model and checkpoint_model[k].shape != state_dict[k].shape:
            print(f"Removing key {k} from pretrained checkpoint")
            del checkpoint_model[k]
    # interpolate position embedding
    interpolate_pos_embed(encoder, checkpoint_model)

    # load pre-trained model
    msg = encoder.load_state_dict(checkpoint_model, strict=False)

    # Freezes Encoder weights
    for name, para in encoder.named_parameters():
        print(name)
        para.requires_grad_(False)

    #load seg model   
    model = maeseg2d3d.__dict__[args.model](encoder=encoder)
    model.to(device)
    
    model_without_ddp = model
    n_parameters = sum(p.numel() for p in model.parameters() if p.requires_grad)

    # print("Model = %s" % str(model_without_ddp))
    print('number of params (M): %.2f' % (n_parameters / 1.e6))

    eff_batch_size = args.batch_size * args.accum_iter * misc.get_world_size()

    print("actual lr: %.2e" % args.lr)

    print("accumulate grad iterations: %d" % args.accum_iter)
    print("effective batch size: %d" % eff_batch_size)

    #加了layer_decay
    param_groups = lrd.param_groups_lrd(model_without_ddp, args.weight_decay,
        layer_decay=args.layer_decay
    )
    # param_groups = optim_factory.param_groups_weight_decay(
    #     model_without_ddp, args.weight_decay)
 
    optimizer = torch.optim.AdamW(param_groups, lr=args.lr)
    print("查看optimizer = ",optimizer)
    loss_scaler = NativeScaler() 


    misc.load_model(args=args, model_without_ddp=model_without_ddp, optimizer=optimizer, loss_scaler=loss_scaler)

    print(f"Start training for {args.epochs} epochs")
    dice_list = []
    start_time = time.time()

    for epoch in range(args.start_epoch, args.epochs):
        #----------------------------训练---------------------------------------------
        model.train()
        metric_logger = misc.MetricLogger(delimiter="  ")
        metric_logger.add_meter('lr', misc.SmoothedValue(window_size=1, fmt='{value:.6f}'))
        accum_iter = args.accum_iter
        optimizer.zero_grad()#优化器清零
        if log_writer is not None:
            print('log_dir: {}'.format(log_writer.log_dir))

        for data_iter_step,data in enumerate(train_loader):
            if data_iter_step % accum_iter == 0:
                lr_sched.adjust_learning_rate(optimizer, data_iter_step / len(train_loader) + epoch, args)
            samples = data["image"]  # 我自己的数据是data["image"]表示图片
            labeles = data["mask"]
            # print("mask.shape = ",labeles.shape)
            # print("samples.shape = ",samples.shape)
            # print("mask.type = ",labeles.dtype)
            samples = samples.to(device, non_blocking=True)
            labeles = labeles.to(device, non_blocking=True)

            with torch.cuda.amp.autocast():
                loss, _,  = model(samples, labeles)

            loss_value = loss.item()

            if not math.isfinite(loss_value):
                print("Loss is {}, stopping training".format(loss_value))
                sys.exit(1)

            loss /= accum_iter
            loss_scaler(loss, optimizer, parameters=model.parameters(),update_grad=(data_iter_step + 1) % accum_iter == 0)

            if (data_iter_step + 1) % accum_iter == 0:
                optimizer.zero_grad()

            torch.cuda.synchronize()

            metric_logger.update(loss=loss_value)

            lr = optimizer.param_groups[0]["lr"]
            metric_logger.update(lr=lr)

            loss_value_reduce = misc.all_reduce_mean(loss_value)

            if log_writer is not None :
                """ We use epoch_1000x as the x-axis in tensorboard.
                This calibrates different curves when batch size changes.
                """
                epoch_1000x = int(
                    (data_iter_step / len(train_loader) + epoch) * 1000)
                log_writer.add_scalar('train_loss', loss_value_reduce, epoch_1000x)
                log_writer.add_scalar('lr', lr, epoch_1000x)

        # gather the stats from all processes
        metric_logger.synchronize_between_processes()
        print("Averaged stats:", metric_logger)
        train_stats = {k: meter.global_avg for k, meter in metric_logger.meters.items()}

        #----------------------------验证-----------------------------------------------
        #每4个epoch进行一次验证
        if(epoch%4==0):
            with torch.no_grad(): #表示在验证的时候不需要梯度计算
                model.eval()
                dice_score = 0.
                iou_score = 0.
                for data in valid_loader:
                    valid_image = data["image"]
                    valid_target = data["mask"]

                    valid_image = valid_image.to(device, non_blocking=True)
                    valid_target = valid_target.to(device, non_blocking=True)

                    _,out = model(valid_image, valid_target) #[N,196,256]
                    out = model.unpatchify3D(out) #[N,1,224,224]
                    dice_score += dice_coef_metric(out.cpu(), valid_target.cpu())
                    iou_score += jaccard_coef_metric(out.cpu(), valid_target.cpu())
                
                dice_score /= len(valid_loader)
                iou_score /= len(valid_loader)
                print("epoch=", epoch,
                    "dice_score=", dice_score,
                    "iou_score=", iou_score)

                print("------------------------------------------------------------------")
                log_writer.add_scalar(tag="dice_scalar", scalar_value=dice_score, global_step=epoch)
                log_writer.add_scalar(tag="iou_scalar", scalar_value=iou_score, global_step=epoch)
                #原作者的save方法,封装更多内容 
                misc.save_model(args=args, model=model, model_without_ddp=model, optimizer=optimizer,
                loss_scaler=loss_scaler, epoch=epoch)
                #torch官方save方法
                # torch.save(model.state_dict(), './seg_768_512_win4_b6_3d_cc359_005data/' +
                #                     str(epoch) + 'ViT' + str(dice_score) + '.pth')
                

            #早停
            if epoch > 20:
                min = 999
                for i in range(int(epoch/4 - 5) , int(epoch/4 - 1) ):
                    if dice_list[i] < min:
                        min = dice_list[i]
                if dice_score < min:
                    lr /= 10
                    print(lr)
                    if lr < 1e-8:
                        torch.save(model.state_dict(), '/data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_015data/' +
                                    str(epoch) + 'ViT' + str(dice_score) + '.pth')
                        break

            dice_list.append(dice_score)#依次放入epoch为0 4 8 12 16 20 24....

        log_stats = {**{f'train_{k}': v for k, v in train_stats.items()},
                     'epoch': epoch, }

        if args.output_dir and misc.is_main_process():
            if log_writer is not None:
                log_writer.flush()
            with open(os.path.join(args.output_dir, "log.txt"), mode="a", encoding="utf-8") as f:
                f.write(json.dumps(log_stats) + "\n")

    total_time = time.time() - start_time
    total_time_str = str(datetime.timedelta(seconds=int(total_time)))
    print('Training time {}'.format(total_time_str))
# Out:
# [Warning] Fused window process have not been installed. Please refer to get_started.md for installation.

# %%
args = get_args_parser()
args = args.parse_args(args=[])
if args.output_dir:
    Path(args.output_dir).mkdir(parents=True, exist_ok=True)
main(args)
# Out:
# Load pre-trained checkpoint from: /data/zhanghao/skull_project/mae-main/pretrain_model/oasis_cc359_half_pretrain_out_norm/checkpoint-399.pth
# number of params (M): 38.36
# actual lr: 1.00e-04
# accumulate grad iterations: 1
# effective batch size: 64
# 查看optimizer =  AdamW (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 1.0
#     weight_decay: 0.0
#
# Parameter Group 1
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 1.0
#     weight_decay: 0.05
#
# Parameter Group 2
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.0625
#     weight_decay: 0.0
#
# Parameter Group 3
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.0625
#     weight_decay: 0.05
#
# Parameter Group 4
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.125
#     weight_decay: 0.0
#
# Parameter Group 5
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.125
#     weight_decay: 0.05
#
# Parameter Group 6
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.25
#     weight_decay: 0.0
#
# Parameter Group 7
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.25
#     weight_decay: 0.05
#
# Parameter Group 8
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.5
#     weight_decay: 0.0
#
# Parameter Group 9
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     lr_scale: 0.5
#     weight_decay: 0.05
# )
# Start training for 400 epochs
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000019  loss: 0.7339 (0.7325)
# epoch= 0 dice_score= 0.32774485197178155 iou_score= 0.19626163604647615
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000039  loss: 0.6524 (0.6829)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000059  loss: 0.5607 (0.5869)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000079  loss: 0.3896 (0.4081)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000099  loss: 0.2952 (0.3479)
# epoch= 4 dice_score= 0.7168781424677649 iou_score= 0.5644164944803992
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000100  loss: 0.2848 (0.3203)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000100  loss: 0.2361 (0.2584)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000100  loss: 0.2353 (0.2504)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000100  loss: 0.2034 (0.2064)
# epoch= 8 dice_score= 0.8288072111994721 iou_score= 0.7099462650543036
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000100  loss: 0.1754 (0.2012)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000100  loss: 0.1682 (0.1848)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000100  loss: 0.

# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000011  loss: 0.0241 (0.0253)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000010  loss: 0.0227 (0.0245)
# epoch= 320 dice_score= 0.9635969954867696 iou_score= 0.9299107346423837
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000010  loss: 0.0235 (0.0247)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000010  loss: 0.0235 (0.0251)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000010  loss: 0.0244 (0.0249)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000010  loss: 0.0233 (0.0243)
# epoch= 324 dice_score= 0.9630479743314344 iou_score= 0.9289169006569441
# ------------------------------------------------------------------
# 9.55664323720983e-07
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000009  loss: 0.0251 (0.0249)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000009  loss: 0.0237 (0.0249)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000009  loss: 0.0236 (0.0246)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000009  loss: 0.0235 (0.0248)
# epoch= 328 dice_score= 0.9636383264563805 iou_score= 0.9299860125364259
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000008  loss: 0.0224 (0.0249)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000008  loss: 0.0229 (0.0242)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000008  loss: 0.0232 (0.0244)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000008  loss: 0.0245 (0.0253)
# epoch= 332 dice_score= 0.9631589748138605 iou_score= 0.9291038180506507
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000008  loss: 0.0228 (0.0244)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000007  loss: 0.0229 (0.0241)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000007  loss: 0.0238 (0.0242)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000007  loss: 0.0238 (0.0241)
# epoch= 336 dice_score= 0.9635994503664416 iou_score= 0.9299213747645534
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000007  loss: 0.0243 (0.0243)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000007  loss: 0.0240 (0.0243)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000007  loss: 0.0242 (0.0242)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000006  loss: 0.0234 (0.0237)
# epoch= 340 dice_score= 0.9637005287547444 iou_score= 0.9301070265991743
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000006  loss: 0.0235 (0.0239)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000006  loss: 0.0238 (0.0239)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000006  loss: 0.0227 (0.0246)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000006  loss: 0.0231 (0.0237)
# epoch= 344 dice_score= 0.9636581332184547 iou_score= 0.9300336408060651
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000006  loss: 0.0241 (0.0237)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000005  loss: 0.0238 (0.0238)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000005  loss: 0.0241 (0.0245)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000005  loss: 0.0234 (0.0242)
# epoch= 348 dice_score= 0.963492288145908 iou_score= 0.9297308894090874
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000005  loss: 0.0222 (0.0235)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000005  loss: 0.0246 (0.0241)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000005  loss: 0.0232 (0.0239)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000004  loss: 0.0234 (0.0242)
# epoch= 352 dice_score= 0.9638217507406722 iou_score= 0.930329465588858
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000004  loss: 0.0228 (0.0237)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000004  loss: 0.0235 (0.0237)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000004  loss: 0.0230 (0.0236)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000004  loss: 0.0234 (0.0239)
# epoch= 356 dice_score= 0.9635937269343886 iou_score= 0.929912737635679
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000004  loss: 0.0232 (0.0237)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000004  loss: 0.0238 (0.0243)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000003  loss: 0.0238 (0.0238)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000003  loss: 0.0228 (0.0245)
# epoch= 360 dice_score= 0.9638209897418355 iou_score= 0.9303323598795159
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000003  loss: 0.0224 (0.0240)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000003  loss: 0.0223 (0.0241)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000003  loss: 0.0226 (0.0244)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000003  loss: 0.0227 (0.0238)
# epoch= 364 dice_score= 0.9638497247252353 iou_score= 0.9303855979165365
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000003  loss: 0.0227 (0.0236)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000003  loss: 0.0249 (0.0241)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000003  loss: 0.0231 (0.0236)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000003  loss: 0.0229 (0.0240)
# epoch= 368 dice_score= 0.9637982166090677 iou_score= 0.9302910039591235
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000002  loss: 0.0233 (0.0236)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000002  loss: 0.0232 (0.0234)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000002  loss: 0.0224 (0.0239)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000002  loss: 0.0232 (0.0240)
# epoch= 372 dice_score= 0.9636422160059906 iou_score= 0.9300050735473633
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000002  loss: 0.0220 (0.0236)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000002  loss: 0.0223 (0.0237)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000002  loss: 0.0226 (0.0237)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000002  loss: 0.0234 (0.0240)
# epoch= 376 dice_score= 0.9638947303905043 iou_score= 0.930469410364018
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000002  loss: 0.0229 (0.0239)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000002  loss: 0.0230 (0.0234)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000002  loss: 0.0231 (0.0242)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000002  loss: 0.0235 (0.0235)
# epoch= 380 dice_score= 0.9638753325440163 iou_score= 0.9304345763006876
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000002  loss: 0.0231 (0.0236)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0229 (0.0233)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0238 (0.0239)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0237 (0.0235)
# epoch= 384 dice_score= 0.9639772925266 iou_score= 0.9306201006090918
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0227 (0.0236)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0225 (0.0233)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0226 (0.0234)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0233 (0.0235)
# epoch= 388 dice_score= 0.9638123387514159 iou_score= 0.9303196183470792
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0244 (0.0235)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0234 (0.0239)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0226 (0.0234)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0228 (0.0239)
# epoch= 392 dice_score= 0.9638392162877459 iou_score= 0.9303652269895687
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0232 (0.0234)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0225 (0.0235)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0227 (0.0239)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0221 (0.0233)
# epoch= 396 dice_score= 0.9639189354209012 iou_score= 0.9305144492969957
# ------------------------------------------------------------------
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0238 (0.0241)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0221 (0.0236)
# log_dir: /data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/
# Averaged stats: lr: 0.000001  loss: 0.0237 (0.0235)
# Training time 2:53:05

# %% [markdown]
# # 测试

# %%
# Copyright (c) Meta Platforms, Inc. and affiliates.
# All rights reserved.

# This source code is licensed under the license found in the
# LICENSE file in the root directory of this source tree.
# --------------------------------------------------------
# References:
# DeiT: https://github.com/facebookresearch/deit
# BEiT: https://github.com/microsoft/unilm/tree/master/beit
# --------------------------------------------------------

import timm.optim.optim_factory as optim_factory
import argparse
import datetime
import json
import numpy as np
import os
import time
from pathlib import Path

import torch
import torch.backends.cudnn as cudnn
from torch.utils.tensorboard import SummaryWriter

import timm

# assert timm.__version__ == "0.3.2" # version check
from timm.models.layers import trunc_normal_
from timm.data.mixup import Mixup
from timm.loss import LabelSmoothingCrossEntropy, SoftTargetCrossEntropy

import util.lr_decay as lrd
import util.misc as misc
from util.datasets import build_dataset
from util.pos_embed import interpolate_pos_embed
from util.misc import NativeScalerWithGradNormCount as NativeScaler

import models_vit

from engine_finetune import train_one_epoch, evaluate
from ast import arg
import my_seg_vit
import util.lr_sched as lr_sched
import math
import sys
from my_metric import dice_coef_metric,jaccard_coef_metric
import seg3d_2dencoder 
import maeseg2d3d
# Out:
# [Warning] Fused window process have not been installed. Please refer to get_started.md for installation.

# %%
from util.ccdataset3d import *
from my_metric import dice_coef_metric,jaccard_coef_metric
train_path, valid_path, test_path = getPathList()

train_loader,valid_loader,test_loader = getDataloader(
    train_path,valid_path,test_path
)
len(train_loader),len(valid_loader),len(test_loader)
#(1,1,160,224,224)
# Out:
# (274, 43, 42)

# %%
from email.policy import strict


encoder_str='mae_vit_medical_half_patch16'
encoder_path='/data/zhanghao/skull_project/mae-main/pretrain_model/oasis_cc359_half_pretrain_out/checkpoint-399.pth'
encoder = seg3d_2dencoder.__dict__[encoder_str](lossforpatch = False)
encoder.load_state_dict(torch.load(encoder_path),strict=False)
model_str='mae_vit3d_medical_768_512_windowsize4'
model_path='/data/zhanghao/skull_project/mae-main/base_line/seg_768_512_win4_b6_3d_cc359_010data_half_norm/checkpoint-296.pth'
model = maeseg2d3d.__dict__[model_str](encoder= encoder)
model.load_state_dict(torch.load(model_path)['model'])
model = model.cuda(0)

# %%
with torch.no_grad(): #表示在验证的时候不需要梯度计算
    model.eval()
    dice_score = 0.
    iou_score = 0.

    for data in test_loader:
        test_image = data["image"]
        test_target = data["mask"]

        test_image = test_image.to('cuda:0', non_blocking=True)
        test_target = test_target.to('cuda:0', non_blocking=True)

        _,out = model(test_image, test_target) #[N,196,256]
        out = model.unpatchify3D(out) #[N,1,224,224]

        
        dice_score += dice_coef_metric(out.cpu(), test_target.cpu())
        iou_score += jaccard_coef_metric(out.cpu(), test_target.cpu())
        print(dice_coef_metric(out.cpu(), test_target.cpu()))
    
    dice_score /= len(test_loader)
    iou_score /= len(test_loader)
    print(
        "dice_score=", dice_score,
        "iou_score=", iou_score)
# Out:
# 0.9373306
# 0.9666672
# 0.9660876
# 0.9636513
# 0.9702205
# 0.97128195
# 0.87124795
# 0.97132987
# 0.96690845
# 0.9701062
# 0.96015173
# 0.9704222
# 0.9508068
# 0.9762645
# 0.9618097
# 0.97303677
# 0.953014
# 0.9627092
# 0.9712228
# 0.95986974
# 0.9517128
# 0.95912147
# 0.95780337
# 0.94460076
# 0.95705956
# 0.97212344
# 0.95565945
# 0.96152115
# 0.97098047
# 0.965125
# 0.9622765
# 0.96575737
# 0.9746117
# 0.95353436
# 0.96384215
# 0.9425042
# 0.95558953
# 0.96402895
# 0.95320743
# 0.965812
# 0.95933664
# 0.9612794
# dice_score= 0.9598006379036677 iou_score= 0.923155155919847
